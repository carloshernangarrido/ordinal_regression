# %%
import pandas as pd
from os import path
import matplotlib.pyplot as plt
from scipy import signal, interpolate
from scipy.spatial.distance import cdist
import numpy as np
import folium
from sklearn.preprocessing import MinMaxScaler

# %%
source_path = r"C:\Users\joses\Mi unidad\TRABAJO\49_profile_estimation\TRABAJO\car_models\synthetic_dataset\four_ramps_cwl_slow"

win_len = 500

speed_stopped_th = .1 # m/s

# %% [markdown]
# # Data Extraction

# %%
subtract_g = False
fs_acc = 100 # sps

# Dataset 1
i_ini, i_fin = 10, 3000 # s
acc_orig_df_1 = pd.read_csv(path.join(source_path, "0/AccelerometerUncalibrated.csv")).iloc[i_ini*fs_acc:i_fin*fs_acc, :].reset_index()
if subtract_g:
    acc_orig_df_1['z'] = acc_orig_df_1['z'] - 9.81
loc_orig_df_1 = pd.read_csv(path.join(source_path, "0/Location.csv")).iloc[i_ini:i_fin, :].reset_index()
loc_orig_df_1 = loc_orig_df_1.loc[loc_orig_df_1['speed'] > speed_stopped_th].reset_index()

# Dataset 2
i_ini, i_fin = 10, 1700 # s
acc_orig_df_2 = pd.read_csv(path.join(source_path, "1/AccelerometerUncalibrated.csv")).iloc[i_ini*fs_acc:i_fin*fs_acc, :].reset_index()
if subtract_g:
    acc_orig_df_2['z'] = acc_orig_df_2['z'] - 9.81
loc_orig_df_2 = pd.read_csv(path.join(source_path, "1/Location.csv")).iloc[i_ini:i_fin, :].reset_index()
loc_orig_df_2 = loc_orig_df_2.loc[loc_orig_df_2['speed'] > speed_stopped_th].reset_index()

plt.plot(loc_orig_df_1['longitude'], loc_orig_df_1['latitude'], label='dataset_1')
plt.plot(loc_orig_df_2['longitude'], loc_orig_df_2['latitude'], label='dataset_2')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.legend()
plt.show()

# %% [markdown]
# ## Raw Visualization

# %%
fig, ax = plt.subplots(1, 2, sharey='row')
ax[0].plot(acc_orig_df_1['seconds_elapsed'], acc_orig_df_1['z'])
ax[0].plot(loc_orig_df_1['seconds_elapsed'], loc_orig_df_1['speed'])
ax[1].plot(acc_orig_df_2['seconds_elapsed'], acc_orig_df_2['z'])
ax[1].plot(loc_orig_df_2['seconds_elapsed'], loc_orig_df_2['speed'])

# %% [markdown]
# # Feature extraction

# %%
# RMS of acceleration
def rolling_rms(acc_orig_df):
    acc2_cum = np.cumsum(acc_orig_df['z']**2)
    acc_rms = np.zeros(acc_orig_df.shape[0])
    for i in range(acc_orig_df.shape[0]-win_len):
        acc_rms[i+win_len] = np.sqrt((acc2_cum[i+win_len] - acc2_cum[i])/win_len)
    acc_feat_df = pd.DataFrame(data=np.vstack((acc_orig_df['seconds_elapsed'].values, acc_rms)).T, 
                                columns=['seconds_elapsed', 'z_rolling_rms']).fillna(0)
    acc_feat_df.reset_index(inplace=True)
    first_non_zero = np.nonzero(acc_feat_df['z_rolling_rms'].values)[0][0]
    acc_feat_df['z_rolling_rms'].values[:first_non_zero] = acc_feat_df['z_rolling_rms'].values[first_non_zero]
    return acc_feat_df

acc_feat_df_1, acc_feat_df_2 = rolling_rms(acc_orig_df_1), rolling_rms(acc_orig_df_2)

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 5), sharex='all', sharey='row')
ax[0,0].plot(loc_orig_df_1['seconds_elapsed'], loc_orig_df_1['speed'])
ax[1,0].plot(acc_orig_df_1['seconds_elapsed'], acc_orig_df_1['z'])
ax[1,0].plot(acc_feat_df_1['seconds_elapsed'], acc_feat_df_1['z_rolling_rms'])
# ax[1,0].set_xlim([0, 200])
ax[0,1].plot(loc_orig_df_2['seconds_elapsed'], loc_orig_df_2['speed'])
ax[1,1].plot(acc_orig_df_2['seconds_elapsed'], acc_orig_df_2['z'])
ax[1,1].plot(acc_feat_df_2['seconds_elapsed'], acc_feat_df_2['z_rolling_rms'])
# ax[1,1].set_xlim([0, 60])
plt.show()

# %% [markdown]
# ### Scatter analysis

# %% [markdown]
# #### Low frequency

# %%
def calc_features_lf_n(loc_orig_df_n, acc_feat_df_n):
    features_lf_n = loc_orig_df_n.loc[:, :]
    features_lf_n['z_rolling_rms'] = \
    np.interp(x=loc_orig_df_n['seconds_elapsed'], 
              xp=acc_feat_df_n['seconds_elapsed'].values-((win_len/fs_acc)/2), fp=acc_feat_df_n['z_rolling_rms'])
    features_lf_n = features_lf_n.drop(columns=['level_0']).reset_index()
    return features_lf_n


features_lf_1, features_lf_2 = calc_features_lf_n(loc_orig_df_1, acc_feat_df_1), calc_features_lf_n(loc_orig_df_2, acc_feat_df_2)


fig, ax = plt.subplots(2, 2, figsize=(10, 5), sharex='all', sharey='row')
ax[0,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['speed'])
ax[0,0].set_ylabel('speed (m/s)')
ax[1,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['z_rolling_rms'])
# ax[1,1].set_ylabel('rms acc. (m/s$^2$)')
ax[0,1].plot(features_lf_2['seconds_elapsed'], features_lf_2['speed'])
# ax[0,1].set_ylabel('speed (m/s)')
ax[1,1].plot(features_lf_2['seconds_elapsed'], features_lf_2['z_rolling_rms'])
ax[1,0].set_ylabel('rms acc. (m/s$^2$)')
ax[1,0].set_xlabel('time (s)')
ax[1,1].set_xlabel('time (s)')

plt.show()

fig, ax = plt.subplots(1, 2, figsize=(10, 5), sharex='all', sharey='all')
ax[0].plot(features_lf_1['z_rolling_rms'], features_lf_1['speed'], linestyle='-', marker='.')
ax[0].set_xlabel('rms acc. (m/s$^2$)')
ax[0].set_ylabel('speed (m/s)')
ax[1].plot(features_lf_2['z_rolling_rms'], features_lf_2['speed'], linestyle='-', marker='.')
ax[1].set_xlabel('rms acc. (m/s$^2$)')
plt.show()

# %% [markdown]
# ### Location matching

# %%
def times_matches_1_n(loc_orig_df_1, loc_orig_df_n, features_lf_n):
    # Extract coordinates as arrays
    coords_orig = loc_orig_df_1[['latitude', 'longitude']].values
    coords_dest = loc_orig_df_n[['latitude', 'longitude']].values

    # Compute pairwise distances
    distances = cdist(coords_orig, coords_dest, metric='euclidean')

    # Find the nearest point for each origin point
    nearest_indices = distances.argmin(axis=1)
    nearest_distances = distances.min(axis=1)

    # Build a dictionary of time matches
    time_matches_dict = {}
    for i, (dist, idx) in enumerate(zip(nearest_distances, nearest_indices)):
        orig_time = loc_orig_df_1.iloc[i]['seconds_elapsed']
        dest_time = loc_orig_df_n.iloc[idx]['seconds_elapsed']
        time_matches_dict[orig_time] = dest_time

    # location matching
    loc_orig_df_n_matched = loc_orig_df_1.copy()
    for index, row in loc_orig_df_1.iterrows():
        seconds_elapsed_1 = row['seconds_elapsed']
        if index == len(loc_orig_df_n_matched):
            break
        loc_orig_df_n_matched.iloc[index] = loc_orig_df_n.loc[loc_orig_df_n['seconds_elapsed'] == time_matches_dict[seconds_elapsed_1]].values[0]

    # feature matching
    features_lf_n_matched = features_lf_1.copy()
    for index, row in features_lf_1.iterrows():
        seconds_elapsed_1 = row['seconds_elapsed']
        features_lf_n_matched.iloc[index] = features_lf_n.loc[features_lf_n['seconds_elapsed'] == time_matches_dict[seconds_elapsed_1]].values[0]

    return time_matches_dict, loc_orig_df_n_matched, features_lf_n_matched


time_matches_dict, loc_orig_df_2_matched, features_lf_2_matched = times_matches_1_n(loc_orig_df_1, loc_orig_df_2, features_lf_2)

# %%
  
fig, ax = plt.subplots(2, 2, figsize=(10, 6), sharey='row')
ax[0,0].plot(loc_orig_df_1['latitude'].values)
ax[0,0].plot(loc_orig_df_2['latitude'].values)
ax[1,0].plot(loc_orig_df_1['longitude'].values)
ax[1,0].plot(loc_orig_df_2['longitude'].values)


ax[0,1].plot(loc_orig_df_1['latitude'].values)
ax[0,1].plot(loc_orig_df_2_matched['latitude'].values)
ax[1,1].plot(loc_orig_df_1['longitude'].values)
ax[1,1].plot(loc_orig_df_2_matched['longitude'].values)

ax[0,0].set_ylabel('latitude (deg.)')
ax[1,0].set_ylabel('longitude (deg.)')
ax[1,0].set_xlabel('time (s)')
ax[1,1].set_xlabel('time (s)')
# Out:
# Text(0.5, 0, 'time (s)')

# %% [markdown]
# # Training

# %%
# feature matching
features_lf_2_matched = features_lf_1.copy()
for index, row in features_lf_1.iterrows():
    seconds_elapsed_1 = row['seconds_elapsed']
    features_lf_2_matched.iloc[index] = features_lf_2.loc[features_lf_2['seconds_elapsed'] == time_matches_dict[seconds_elapsed_1]].values[0]

fig, ax = plt.subplots(2, 2, figsize=(10, 5), sharex='col', sharey='row')
ax[0,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['speed'])
ax[0,0].set_ylabel('speed (m/s)')
ax[1,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['z_rolling_rms'])
# ax[1,1].set_ylabel('rms acc. (m/s$^2$)')
ax[0,1].plot(features_lf_2_matched['seconds_elapsed'], features_lf_2_matched['speed'])
# ax[0,1].set_ylabel('speed (m/s)')
ax[1,1].plot(features_lf_2_matched['seconds_elapsed'], features_lf_2_matched['z_rolling_rms'])
ax[1,0].set_ylabel('rms acc. (m/s$^2$)')
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(10, 5), sharex='all', sharey='all')
ax[0].plot(features_lf_1['z_rolling_rms'], features_lf_1['speed'], linestyle='-', marker='.')
ax[0].set_xlabel('rms acc. (m/s$^2$)')
ax[0].set_ylabel('speed (m/s)')
ax[1].plot(features_lf_2_matched['z_rolling_rms'], features_lf_2_matched['speed'], linestyle='-', marker='.')
ax[1].set_xlabel('rms acc. (m/s$^2$)')
plt.show()

# %% [markdown]
# ### Datasets

# %%
X_equal = np.array([features_lf_1.loc[:, 'speed'].values, features_lf_1.loc[:, 'z_rolling_rms'].values, 
                    features_lf_2_matched.loc[:, 'speed'].values, features_lf_2_matched.loc[:, 'z_rolling_rms'].values]).T
y_equal = np.zeros((X_equal.shape[0], 1))

fig, ax = plt.subplots(2, 1, figsize=(15,5))
ax[0].plot(X_equal[:, 0], color='blue', linestyle='-', label='speed_1')
ax[0].plot(X_equal[:, 2], color='red', linestyle='-', label='speed_2')
ax[0].legend()
ax[1].plot(X_equal[:, 1], color='blue', linestyle='-', label='acc_1')
ax[1].plot(X_equal[:, 3], color='red', linestyle='-', label='acc_2')
ax[1].set_xlabel('sample')
ax[1].legend()

scaler_X = MinMaxScaler((-1,1))
scaler_X.fit(np.vstack((X_equal[:, :2], X_equal[:, 2:])))
X_equal = np.hstack((scaler_X.transform(X_equal[:, :2]), scaler_X.transform(X_equal[:, 2:])))

fig, ax = plt.subplots(2, 1, figsize=(15,5))
ax[0].plot(X_equal[:, 0], color='blue', linestyle='-', label='speed_1')
ax[0].plot(X_equal[:, 2], color='red', linestyle='-', label='speed_2')
ax[0].legend()
ax[1].plot(X_equal[:, 1], color='blue', linestyle='-', label='acc_1')
ax[1].plot(X_equal[:, 3], color='red', linestyle='-', label='acc_2')
ax[1].set_xlabel('sample')
ax[1].legend()

# %% [markdown]
# #### Ordinal labels

# %%
from sklearn.model_selection import train_test_split
scaler_X.inverse_transform([[min([min(X_equal[:,0]), min(X_equal[:,2])]), min([min(X_equal[:,1]), min(X_equal[:,3])])]])
# Out:
# array([[0.10000213, 0.03632505]])

# %%
speed_tol = .01 # 
acc_tol = .01 # 

grid_length = X_equal.shape[0]
speed_grid = np.random.uniform(min([min(X_equal[:,0]), min(X_equal[:,2])]), max([max(X_equal[:,0]), max(X_equal[:,2])]), (grid_length,1))
vib_grid = np.random.uniform(min([min(X_equal[:,1]), min(X_equal[:,3])]), max([max(X_equal[:,1]), max(X_equal[:,3])]), (grid_length,1))
X_grid = np.hstack((speed_grid, vib_grid, speed_grid, vib_grid))

X_ordinal = []
y_ordinal = []
for x1 in X_grid[:, :2]:
    for x2 in X_grid[:, 2:]:
        if abs(x1[0] - x2[0]) < speed_tol:
            if x1[1] > x2[1] + acc_tol:
                X_ordinal.append(np.hstack((x1, x2)))
                y_ordinal.append(1.)
            elif x1[1] < x2[1] - acc_tol:
                X_ordinal.append(np.hstack((x1, x2)))
                y_ordinal.append(-1.)
X_ordinal = np.array(X_ordinal)
y_ordinal = np.array(y_ordinal).reshape((-1, 1))

X_ordinal, _, y_ordinal, _ = train_test_split(X_ordinal, y_ordinal, test_size=0.995, shuffle=True)


X = np.vstack((X_equal, X_ordinal))
y = np.vstack((y_equal, y_ordinal))
shuffler = np.arange(X.shape[0])
np.random.default_rng().shuffle(shuffler)
X = X[shuffler, :]
y = y[shuffler, :]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=True)

plt.hist(y_train)
plt.hist(y_test)
# Out:
# (array([  5.,   0.,   0.,   0.,   0., 122.,   0.,   0.,   0.,  13.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Model definition

# %%
import keras


x1_nn_input = keras.layers.Input(shape=(2,))
x2_nn_input = keras.layers.Input(shape=(2,))

activation = 'tanh'
reg = None
dropout = 0.0
shared_layers = [
                 keras.layers.Dense(100, activation=activation, kernel_regularizer=reg, bias_regularizer=reg, activity_regularizer=reg),
                #  keras.layers.Dropout(dropout),
                #  keras.layers.BatchNormalization(),
                 keras.layers.Dense(100, activation=activation, kernel_regularizer=reg, bias_regularizer=reg, activity_regularizer=reg),
                #  keras.layers.Dropout(dropout),
                #  keras.layers.BatchNormalization(),
                 keras.layers.Dense(100, activation=activation, kernel_regularizer=reg, bias_regularizer=reg, activity_regularizer=reg),
                #  keras.layers.Dropout(dropout),
                #  keras.layers.BatchNormalization(),
                 keras.layers.Dense(1, activation='linear', kernel_regularizer=reg, bias_regularizer=reg, activity_regularizer=reg)]
first = True
for layer in shared_layers:
    if first:
        x1_nn = layer(x1_nn_input)
        x2_nn = layer(x2_nn_input)
        first = False    
    else:
        x1_nn = layer(x1_nn)
        x2_nn = layer(x2_nn)

y_nn = keras.layers.Lambda(lambda x12: keras.backend.tanh(x12[0] - x12[1]), name='ranker')((x1_nn, x2_nn))

model = keras.models.Model(inputs=[x1_nn_input, x2_nn_input], outputs=[y_nn])
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 2)]                  0         []
#
#  input_4 (InputLayer)        [(None, 2)]                  0         []
#
#  dense_4 (Dense)             (None, 100)                  300       ['input_3[0][0]',
#                                                                      'input_4[0][0]']
#
#  dense_5 (Dense)             (None, 100)                  10100     ['dense_4[0][0]',
#                                                                      'dense_4[1][0]']
#
#  dense_6 (Dense)             (None, 100)                  10100     ['dense_5[0][0]',
#                                                                      'dense_5[1][0]']
#
#  dense_7 (Dense)             (None, 1)                    101       ['dense_6[0][0]',
#                                                                      'dense_6[1][0]']
#
#  ranker (Lambda)             (None, 1)                    0         ['dense_7[0][0]',
#                                                                      'dense_7[1][0]']
#
# ==================================================================================================
# Total params: 20601 (80.47 KB)
# Trainable params: 20601 (80.47 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, to_file='model.pdf',
                        show_shapes=True,
                        show_dtype=False,
                        show_layer_names=True,
                        expand_nested=True,
                        dpi=96,
                        layer_range=None,
                        show_layer_activations=True,
                        show_trainable=True)

# %%
model_x1 = keras.models.Model(inputs=[x1_nn_input], outputs=[x1_nn])
model_x1.build(input_shape=x1_nn_input.shape)
# model_x1.summary()

# %% [markdown]
# ## Model training

# %%
learning_rate = .1
batch_size = X_train.shape[0]
epochs = 1000
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.9,
                                              patience=50, verbose=1,min_lr=1e-6)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=200)

model.compile(optimizer=keras.optimizers.SGD(learning_rate=learning_rate), loss='mse')
history = model.fit(x=[X_train[:, :2], X_train[:, 2:]], y=[y_train], batch_size=batch_size, epochs=epochs, 
                    validation_split=0.1,
                    callbacks=[reduce_lr, early_stopping])
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 4s 4s/step - loss: 0.1632 - val_loss: 0.1087 - lr: 0.1000
# Epoch 2/1000
# 1/1 [==============================] - 0s 142ms/step - loss: 0.1161 - val_loss: 0.0930 - lr: 0.1000
# Epoch 3/1000
# 1/1 [==============================] - 0s 212ms/step - loss: 0.1001 - val_loss: 0.0828 - lr: 0.1000
# Epoch 4/1000
# 1/1 [==============================] - 0s 201ms/step - loss: 0.0897 - val_loss: 0.0764 - lr: 0.1000
# Epoch 5/1000
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0830 - val_loss: 0.0723 - lr: 0.1000
# Epoch 6/1000
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0788 - val_loss: 0.0697 - lr: 0.1000
# Epoch 7/1000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0760 - val_loss: 0.0680 - lr: 0.1000
# Epoch 8/1000
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0742 - val_loss: 0.0669 - lr: 0.1000
# Epoch 9/1000
# 1/1 [==============================] - 0s 154ms/step - loss: 0.0731 - val_loss: 0.0662 - lr: 0.1000
# Epoch 10/1000
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0723 - val_loss: 0.0657 - lr: 0.1000
# Epoch 11/1000
# 1/1 [==============================] - 0s 199ms/step - loss: 0.0717 - val_loss: 0.0654 - lr: 0.1000
# Epoch 12/1000
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0714 - val_loss: 0.0652 - lr: 0.1000
# Epoch 13/1000
# 1/1 [==============================] - 0s 199ms/step - loss: 0.0711 - val_loss: 0.0650 - lr: 0.1000
# Epoch 14/1000
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0710 - val_loss: 0.0649 - lr: 0.1000
# Epoch 15/1000
# 1/1 [==============================] - 0s 225ms/step - loss: 0.0708 - val_loss: 0.0649 - lr: 0.1000
# Epoch 16/1000
# 1/1 [==============================] - 0s 161ms/step - loss: 0.0707 - val_loss: 0.0648 - lr: 0.1000
# Epoch 17/1000
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0707 - val_loss: 0.0648 - lr: 0.1000
# Epoch 18/1000
# 1/1 [==============================] - 0s 170ms/step - loss: 0.0706 - val_loss: 0.0647 - lr: 0.1000
# Epoch 19/1000
# 1/1 [==============================] - 0s 254ms/step - loss: 0.0706 - val_loss: 0.0647 - lr: 0.1000
# Epoch 20/1000
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0706 - val_loss: 0.0647 - lr: 0.1000
# Epoch 21/1000
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0705 - val_loss: 0.0647 - lr: 0.1000
# Epoch 22/1000
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0705 - val_loss: 0.0647 - lr: 0.1000
# Epoch 23/1000
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0705 - val_loss: 0.0647 - lr: 0.1000
# Epoch 24/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0705 - val_loss: 0.0646 - lr: 0.1000
# Epoch 25/1000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0704 - val_loss: 0.0646 - lr: 0.1000
# Epoch 26/1000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0704 - val_loss: 0.0646 - lr: 0.1000
# Epoch 27/1000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0704 - val_loss: 0.0646 - lr: 0.1000
# Epoch 28/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0704 - val_loss: 0.0646 - lr: 0.1000
# Epoch 29/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0704 - val_loss: 0.0646 - lr: 0.1000
# Epoch 30/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0704 - val_loss: 0.0646 - lr: 0.1000
# Epoch 31/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0703 - val_loss: 0.0646 - lr: 0.1000
# Epoch 32/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0703 - val_loss: 0.0645 - lr: 0.1000
# Epoch 33/1000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0703 - val_loss: 0.0645 - lr: 0.1000
# Epoch 34/1000
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0703 - val_loss: 0.0645 - lr: 0.1000
# Epoch 35/1000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0703 - val_loss: 0.0645 - lr: 0.1000
# Epoch 36/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0703 - val_loss: 0.0645 - lr: 0.1000
# Epoch 37/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0702 - val_loss: 0.0645 - lr: 0.1000
# Epoch 38/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0702 - val_loss: 0.0645 - lr: 0.1000
# Epoch 39/1000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0702 - val_loss: 0.0644 - lr: 0.1000
# Epoch 40/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0702 - val_loss: 0.0644 - lr: 0.1000
# Epoch 41/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0702 - val_loss: 0.0644 - lr: 0.1000
# Epoch 42/1000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0702 - val_loss: 0.0644 - lr: 0.1000
# Epoch 43/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0701 - val_loss: 0.0644 - lr: 0.1000
# Epoch 44/1000
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0701 - val_loss: 0.0644 - lr: 0.1000
# Epoch 45/1000
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0701 - val_loss: 0.0644 - lr: 0.1000
# Epoch 46/1000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0701 - val_loss: 0.0644 - lr: 0.1000
# Epoch 47/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0701 - val_loss: 0.0643 - lr: 0.1000
# Epoch 48/1000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0701 - val_loss: 0.0643 - lr: 0.1000
# Epoch 49/1000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0700 - val_loss: 0.0643 - lr: 0.1000
# Epoch 50/1000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0700 - val_loss: 0.0643 - lr: 0.1000
# Epoch 51/1000
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0700 - val_loss: 0.0643 - lr: 0.1000
# Epoch 52/1000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0700 - val_loss: 0.0643 - lr: 0.1000
# Epoch 53/1000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0700 - val_loss: 0.0643 - lr: 0.1000
# Epoch 54/1000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0699 - val_loss: 0.0642 - lr: 0.1000
# Epoch 55/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0699 - val_loss: 0.0642 - lr: 0.1000
# Epoch 56/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0699 - val_loss: 0.0642 - lr: 0.1000
# Epoch 57/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0699 - val_loss: 0.0642 - lr: 0.1000
# Epoch 58/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0699 - val_loss: 0.0642 - lr: 0.1000
# Epoch 59/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0699 - val_loss: 0.0642 - lr: 0.1000
# Epoch 60/1000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0698 - val_loss: 0.0642 - lr: 0.1000
# Epoch 61/1000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0698 - val_loss: 0.0641 - lr: 0.1000
# Epoch 62/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0698 - val_loss: 0.0641 - lr: 0.1000
# Epoch 63/1000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0698 - val_loss: 0.0641 - lr: 0.1000
# Epoch 64/1000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0698 - val_loss: 0.0641 - lr: 0.1000
# Epoch 65/1000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0698 - val_loss: 0.0641 - lr: 0.1000
# Epoch 66/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0697 - val_loss: 0.0641 - lr: 0.1000
# Epoch 67/1000
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0697 - val_loss: 0.0640 - lr: 0.1000
# Epoch 68/1000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0697 - val_loss: 0.0640 - lr: 0.1000
# Epoch 69/1000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0697 - val_loss: 0.0640 - lr: 0.1000
# Epoch 70/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0697 - val_loss: 0.0640 - lr: 0.1000
# Epoch 71/1000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0696 - val_loss: 0.0640 - lr: 0.1000
# Epoch 72/1000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0696 - val_loss: 0.0640 - lr: 0.1000
# Epoch 73/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0696 - val_loss: 0.0640 - lr: 0.1000
# Epoch 74/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0696 - val_loss: 0.0639 - lr: 0.1000
# Epoch 75/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0696 - val_loss: 0.0639 - lr: 0.1000
# Epoch 76/1000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0696 - val_loss: 0.0639 - lr: 0.1000
# Epoch 77/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0695 - val_loss: 0.0639 - lr: 0.1000
# Epoch 78/1000
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0695 - val_loss: 0.0639 - lr: 0.1000
# Epoch 79/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0695 - val_loss: 0.0639 - lr: 0.1000
# Epoch 80/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0695 - val_loss: 0.0638 - lr: 0.1000
# Epoch 81/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0695 - val_loss: 0.0638 - lr: 0.1000
# Epoch 82/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0694 - val_loss: 0.0638 - lr: 0.1000
# Epoch 83/1000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0694 - val_loss: 0.0638 - lr: 0.1000
# Epoch 84/1000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0694 - val_loss: 0.0638 - lr: 0.1000
# Epoch 85/1000
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0694 - val_loss: 0.0638 - lr: 0.1000
# Epoch 86/1000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0694 - val_loss: 0.0637 - lr: 0.1000
# Epoch 87/1000
# 1/1 [==============================] - 0s 217ms/step - loss: 0.0693 - val_loss: 0.0637 - lr: 0.1000
# Epoch 88/1000
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0693 - val_loss: 0.0637 - lr: 0.1000
# Epoch 89/1000
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0693 - val_loss: 0.0637 - lr: 0.1000
# Epoch 90/1000
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0693 - val_loss: 0.0637 - lr: 0.1000
# Epoch 91/1000
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0693 - val_loss: 0.0637 - lr: 0.1000
# Epoch 92/1000
# 1/1 [==============================] - 0s 143ms/step - loss: 0.0692 - val_loss: 0.0636 - lr: 0.1000
# Epoch 93/1000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0692 - val_loss: 0.0636 - lr: 0.1000
# Epoch 94/1000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0692 - val_loss: 0.0636 - lr: 0.1000
# Epoch 95/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0692 - val_loss: 0.0636 - lr: 0.1000
# Epoch 96/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0691 - val_loss: 0.0636 - lr: 0.1000
# Epoch 97/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0691 - val_loss: 0.0635 - lr: 0.1000
# Epoch 98/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0691 - val_loss: 0.0635 - lr: 0.1000
# Epoch 99/1000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0691 - val_loss: 0.0635 - lr: 0.1000
# Epoch 100/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0691 - val_loss: 0.0635 - lr: 0.1000
# Epoch 101/1000
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0690 - val_loss: 0.0635 - lr: 0.1000
# Epoch 102/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0690 - val_loss: 0.0635 - lr: 0.1000
# Epoch 103/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0690 - val_loss: 0.0634 - lr: 0.1000
# Epoch 104/1000
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0690 - val_loss: 0.0634 - lr: 0.1000
# Epoch 105/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0689 - val_loss: 0.0634 - lr: 0.1000
# Epoch 106/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0689 - val_loss: 0.0634 - lr: 0.1000
# Epoch 107/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0689 - val_loss: 0.0634 - lr: 0.1000
# Epoch 108/1000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0689 - val_loss: 0.0633 - lr: 0.1000
# Epoch 109/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0689 - val_loss: 0.0633 - lr: 0.1000
# Epoch 110/1000
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0688 - val_loss: 0.0633 - lr: 0.1000
# Epoch 111/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0688 - val_loss: 0.0633 - lr: 0.1000
# Epoch 112/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0688 - val_loss: 0.0633 - lr: 0.1000
# Epoch 113/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0688 - val_loss: 0.0632 - lr: 0.1000
# Epoch 114/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0687 - val_loss: 0.0632 - lr: 0.1000
# Epoch 115/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0687 - val_loss: 0.0632 - lr: 0.1000
# Epoch 116/1000
# 1/1 [==============================] - 0s 138ms/step - loss: 0.0687 - val_loss: 0.0632 - lr: 0.1000
# Epoch 117/1000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0687 - val_loss: 0.0631 - lr: 0.1000
# Epoch 118/1000
# 1/1 [==============================] - 0s 153ms/step - loss: 0.0686 - val_loss: 0.0631 - lr: 0.1000
# Epoch 119/1000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0686 - val_loss: 0.0631 - lr: 0.1000
# Epoch 120/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0686 - val_loss: 0.0631 - lr: 0.1000
# Epoch 121/1000
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0686 - val_loss: 0.0631 - lr: 0.1000
# Epoch 122/1000
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0685 - val_loss: 0.0630 - lr: 0.1000
# Epoch 123/1000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0685 - val_loss: 0.0630 - lr: 0.1000
# Epoch 124/1000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0685 - val_loss: 0.0630 - lr: 0.1000
# Epoch 125/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0685 - val_loss: 0.0630 - lr: 0.1000
# Epoch 126/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0684 - val_loss: 0.0629 - lr: 0.1000
# Epoch 127/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0684 - val_loss: 0.0629 - lr: 0.1000
# Epoch 128/1000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0684 - val_loss: 0.0629 - lr: 0.1000
# Epoch 129/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0683 - val_loss: 0.0629 - lr: 0.1000
# Epoch 130/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0683 - val_loss: 0.0629 - lr: 0.1000
# Epoch 131/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0683 - val_loss: 0.0628 - lr: 0.1000
# Epoch 132/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0683 - val_loss: 0.0628 - lr: 0.1000
# Epoch 133/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0682 - val_loss: 0.0628 - lr: 0.1000
# Epoch 134/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0682 - val_loss: 0.0628 - lr: 0.1000
# Epoch 135/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0682 - val_loss: 0.0627 - lr: 0.1000
# Epoch 136/1000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0681 - val_loss: 0.0627 - lr: 0.1000
# Epoch 137/1000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0681 - val_loss: 0.0627 - lr: 0.1000
# Epoch 138/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0681 - val_loss: 0.0627 - lr: 0.1000
# Epoch 139/1000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0681 - val_loss: 0.0626 - lr: 0.1000
# Epoch 140/1000
# 1/1 [==============================] - 0s 209ms/step - loss: 0.0680 - val_loss: 0.0626 - lr: 0.1000
# Epoch 141/1000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0680 - val_loss: 0.0626 - lr: 0.1000
# Epoch 142/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0680 - val_loss: 0.0625 - lr: 0.1000
# Epoch 143/1000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0679 - val_loss: 0.0625 - lr: 0.1000
# Epoch 144/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0679 - val_loss: 0.0625 - lr: 0.1000
# Epoch 145/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0679 - val_loss: 0.0625 - lr: 0.1000
# Epoch 146/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0678 - val_loss: 0.0624 - lr: 0.1000
# Epoch 147/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0678 - val_loss: 0.0624 - lr: 0.1000
# Epoch 148/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0678 - val_loss: 0.0624 - lr: 0.1000
# Epoch 149/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0677 - val_loss: 0.0624 - lr: 0.1000
# Epoch 150/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0677 - val_loss: 0.0623 - lr: 0.1000
# Epoch 151/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0677 - val_loss: 0.0623 - lr: 0.1000
# Epoch 152/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0676 - val_loss: 0.0623 - lr: 0.1000
# Epoch 153/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0676 - val_loss: 0.0622 - lr: 0.1000
# Epoch 154/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0676 - val_loss: 0.0622 - lr: 0.1000
# Epoch 155/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0675 - val_loss: 0.0622 - lr: 0.1000
# Epoch 156/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0675 - val_loss: 0.0621 - lr: 0.1000
# Epoch 157/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0675 - val_loss: 0.0621 - lr: 0.1000
# Epoch 158/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0674 - val_loss: 0.0621 - lr: 0.1000
# Epoch 159/1000
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0674 - val_loss: 0.0621 - lr: 0.1000
# Epoch 160/1000
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0673 - val_loss: 0.0620 - lr: 0.1000
# Epoch 161/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0673 - val_loss: 0.0620 - lr: 0.1000
# Epoch 162/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0673 - val_loss: 0.0620 - lr: 0.1000
# Epoch 163/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0672 - val_loss: 0.0619 - lr: 0.1000
# Epoch 164/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0672 - val_loss: 0.0619 - lr: 0.1000
# Epoch 165/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0672 - val_loss: 0.0619 - lr: 0.1000
# Epoch 166/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0671 - val_loss: 0.0618 - lr: 0.1000
# Epoch 167/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0671 - val_loss: 0.0618 - lr: 0.1000
# Epoch 168/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0670 - val_loss: 0.0618 - lr: 0.1000
# Epoch 169/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0670 - val_loss: 0.0617 - lr: 0.1000
# Epoch 170/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0670 - val_loss: 0.0617 - lr: 0.1000
# Epoch 171/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0669 - val_loss: 0.0616 - lr: 0.1000
# Epoch 172/1000
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0669 - val_loss: 0.0616 - lr: 0.1000
# Epoch 173/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0668 - val_loss: 0.0616 - lr: 0.1000
# Epoch 174/1000
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0668 - val_loss: 0.0615 - lr: 0.1000
# Epoch 175/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0668 - val_loss: 0.0615 - lr: 0.1000
# Epoch 176/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0667 - val_loss: 0.0615 - lr: 0.1000
# Epoch 177/1000
# 1/1 [==============================] - 0s 200ms/step - loss: 0.0667 - val_loss: 0.0614 - lr: 0.1000
# Epoch 178/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0666 - val_loss: 0.0614 - lr: 0.1000
# Epoch 179/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0666 - val_loss: 0.0614 - lr: 0.1000
# Epoch 180/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0665 - val_loss: 0.0613 - lr: 0.1000
# Epoch 181/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0665 - val_loss: 0.0613 - lr: 0.1000
# Epoch 182/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0665 - val_loss: 0.0612 - lr: 0.1000
# Epoch 183/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0664 - val_loss: 0.0612 - lr: 0.1000
# Epoch 184/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0664 - val_loss: 0.0612 - lr: 0.1000
# Epoch 185/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0663 - val_loss: 0.0611 - lr: 0.1000
# Epoch 186/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0663 - val_loss: 0.0611 - lr: 0.1000
# Epoch 187/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0662 - val_loss: 0.0610 - lr: 0.1000
# Epoch 188/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0662 - val_loss: 0.0610 - lr: 0.1000
# Epoch 189/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0661 - val_loss: 0.0610 - lr: 0.1000
# Epoch 190/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0661 - val_loss: 0.0609 - lr: 0.1000
# Epoch 191/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0660 - val_loss: 0.0609 - lr: 0.1000
# Epoch 192/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0660 - val_loss: 0.0608 - lr: 0.1000
# Epoch 193/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0659 - val_loss: 0.0608 - lr: 0.1000
# Epoch 194/1000
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0659 - val_loss: 0.0607 - lr: 0.1000
# Epoch 195/1000
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0658 - val_loss: 0.0607 - lr: 0.1000
# Epoch 196/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0658 - val_loss: 0.0607 - lr: 0.1000
# Epoch 197/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0657 - val_loss: 0.0606 - lr: 0.1000
# Epoch 198/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0657 - val_loss: 0.0606 - lr: 0.1000
# Epoch 199/1000
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0656 - val_loss: 0.0605 - lr: 0.1000
# Epoch 200/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0656 - val_loss: 0.0605 - lr: 0.1000
# Epoch 201/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0655 - val_loss: 0.0604 - lr: 0.1000
# Epoch 202/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0655 - val_loss: 0.0604 - lr: 0.1000
# Epoch 203/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0654 - val_loss: 0.0603 - lr: 0.1000
# Epoch 204/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0654 - val_loss: 0.0603 - lr: 0.1000
# Epoch 205/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0653 - val_loss: 0.0602 - lr: 0.1000
# Epoch 206/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0653 - val_loss: 0.0602 - lr: 0.1000
# Epoch 207/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0652 - val_loss: 0.0602 - lr: 0.1000
# Epoch 208/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0651 - val_loss: 0.0601 - lr: 0.1000
# Epoch 209/1000
# 1/1 [==============================] - 0s 198ms/step - loss: 0.0651 - val_loss: 0.0601 - lr: 0.1000
# Epoch 210/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0650 - val_loss: 0.0600 - lr: 0.1000
# Epoch 211/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0650 - val_loss: 0.0600 - lr: 0.1000
# Epoch 212/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0649 - val_loss: 0.0599 - lr: 0.1000
# Epoch 213/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0649 - val_loss: 0.0599 - lr: 0.1000
# Epoch 214/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0648 - val_loss: 0.0598 - lr: 0.1000
# Epoch 215/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0647 - val_loss: 0.0598 - lr: 0.1000
# Epoch 216/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0647 - val_loss: 0.0597 - lr: 0.1000
# Epoch 217/1000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0646 - val_loss: 0.0597 - lr: 0.1000
# Epoch 218/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0646 - val_loss: 0.0596 - lr: 0.1000
# Epoch 219/1000
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0645 - val_loss: 0.0596 - lr: 0.1000
# Epoch 220/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0645 - val_loss: 0.0595 - lr: 0.1000
# Epoch 221/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0644 - val_loss: 0.0595 - lr: 0.1000
# Epoch 222/1000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0643 - val_loss: 0.0594 - lr: 0.1000
# Epoch 223/1000
# 1/1 [==============================] - 0s 164ms/step - loss: 0.0643 - val_loss: 0.0594 - lr: 0.1000
# Epoch 224/1000
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0642 - val_loss: 0.0593 - lr: 0.1000
# Epoch 225/1000
# 1/1 [==============================] - 0s 199ms/step - loss: 0.0642 - val_loss: 0.0593 - lr: 0.1000
# Epoch 226/1000
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0641 - val_loss: 0.0592 - lr: 0.1000
# Epoch 227/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0640 - val_loss: 0.0591 - lr: 0.1000
# Epoch 228/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0640 - val_loss: 0.0591 - lr: 0.1000
# Epoch 229/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0639 - val_loss: 0.0590 - lr: 0.1000
# Epoch 230/1000
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0638 - val_loss: 0.0590 - lr: 0.1000
# Epoch 231/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0638 - val_loss: 0.0589 - lr: 0.1000
# Epoch 232/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0637 - val_loss: 0.0589 - lr: 0.1000
# Epoch 233/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0637 - val_loss: 0.0588 - lr: 0.1000
# Epoch 234/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0636 - val_loss: 0.0588 - lr: 0.1000
# Epoch 235/1000
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0635 - val_loss: 0.0587 - lr: 0.1000
# Epoch 236/1000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0635 - val_loss: 0.0587 - lr: 0.1000
# Epoch 237/1000
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0634 - val_loss: 0.0586 - lr: 0.1000
# Epoch 238/1000
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0633 - val_loss: 0.0586 - lr: 0.1000
# Epoch 239/1000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0633 - val_loss: 0.0585 - lr: 0.1000
# Epoch 240/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0632 - val_loss: 0.0585 - lr: 0.1000
# Epoch 241/1000
# 1/1 [==============================] - 0s 211ms/step - loss: 0.0632 - val_loss: 0.0584 - lr: 0.1000
# Epoch 242/1000
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0631 - val_loss: 0.0583 - lr: 0.1000
# Epoch 243/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0630 - val_loss: 0.0583 - lr: 0.1000
# Epoch 244/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0630 - val_loss: 0.0582 - lr: 0.1000
# Epoch 245/1000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0629 - val_loss: 0.0582 - lr: 0.1000
# Epoch 246/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0628 - val_loss: 0.0581 - lr: 0.1000
# Epoch 247/1000
# 1/1 [==============================] - 0s 175ms/step - loss: 0.0628 - val_loss: 0.0581 - lr: 0.1000
# Epoch 248/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0627 - val_loss: 0.0580 - lr: 0.1000
# Epoch 249/1000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0626 - val_loss: 0.0580 - lr: 0.1000
# Epoch 250/1000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0626 - val_loss: 0.0579 - lr: 0.1000
# Epoch 251/1000
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0625 - val_loss: 0.0579 - lr: 0.1000
# Epoch 252/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0624 - val_loss: 0.0578 - lr: 0.1000
# Epoch 253/1000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0624 - val_loss: 0.0578 - lr: 0.1000
# Epoch 254/1000
# 1/1 [==============================] - 0s 146ms/step - loss: 0.0623 - val_loss: 0.0577 - lr: 0.1000
# Epoch 255/1000
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0623 - val_loss: 0.0577 - lr: 0.1000
# Epoch 256/1000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0622 - val_loss: 0.0576 - lr: 0.1000
# Epoch 257/1000
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0621 - val_loss: 0.0576 - lr: 0.1000
# Epoch 258/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0621 - val_loss: 0.0575 - lr: 0.1000
# Epoch 259/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0620 - val_loss: 0.0574 - lr: 0.1000
# Epoch 260/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0619 - val_loss: 0.0574 - lr: 0.1000
# Epoch 261/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0619 - val_loss: 0.0573 - lr: 0.1000
# Epoch 262/1000
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0618 - val_loss: 0.0573 - lr: 0.1000
# Epoch 263/1000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0618 - val_loss: 0.0572 - lr: 0.1000
# Epoch 264/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0617 - val_loss: 0.0572 - lr: 0.1000
# Epoch 265/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0616 - val_loss: 0.0571 - lr: 0.1000
# Epoch 266/1000
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0616 - val_loss: 0.0571 - lr: 0.1000
# Epoch 267/1000
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0615 - val_loss: 0.0570 - lr: 0.1000
# Epoch 268/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0615 - val_loss: 0.0570 - lr: 0.1000
# Epoch 269/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0614 - val_loss: 0.0570 - lr: 0.1000
# Epoch 270/1000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0613 - val_loss: 0.0569 - lr: 0.1000
# Epoch 271/1000
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0613 - val_loss: 0.0569 - lr: 0.1000
# Epoch 272/1000
# 1/1 [==============================] - 0s 219ms/step - loss: 0.0612 - val_loss: 0.0568 - lr: 0.1000
# Epoch 273/1000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0612 - val_loss: 0.0568 - lr: 0.1000
# Epoch 274/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0611 - val_loss: 0.0567 - lr: 0.1000
# Epoch 275/1000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0611 - val_loss: 0.0567 - lr: 0.1000
# Epoch 276/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0610 - val_loss: 0.0566 - lr: 0.1000
# Epoch 277/1000
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0609 - val_loss: 0.0566 - lr: 0.1000
# Epoch 278/1000
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0609 - val_loss: 0.0565 - lr: 0.1000
# Epoch 279/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0608 - val_loss: 0.0565 - lr: 0.1000
# Epoch 280/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0608 - val_loss: 0.0565 - lr: 0.1000
# Epoch 281/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0607 - val_loss: 0.0564 - lr: 0.1000
# Epoch 282/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0607 - val_loss: 0.0564 - lr: 0.1000
# Epoch 283/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0606 - val_loss: 0.0563 - lr: 0.1000
# Epoch 284/1000
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0606 - val_loss: 0.0563 - lr: 0.1000
# Epoch 285/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0605 - val_loss: 0.0563 - lr: 0.1000
# Epoch 286/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0605 - val_loss: 0.0562 - lr: 0.1000
# Epoch 287/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0604 - val_loss: 0.0562 - lr: 0.1000
# Epoch 288/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0604 - val_loss: 0.0561 - lr: 0.1000
# Epoch 289/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0603 - val_loss: 0.0561 - lr: 0.1000
# Epoch 290/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0603 - val_loss: 0.0561 - lr: 0.1000
# Epoch 291/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0602 - val_loss: 0.0560 - lr: 0.1000
# Epoch 292/1000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0602 - val_loss: 0.0560 - lr: 0.1000
# Epoch 293/1000
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0601 - val_loss: 0.0560 - lr: 0.1000
# Epoch 294/1000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0601 - val_loss: 0.0559 - lr: 0.1000
# Epoch 295/1000
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0600 - val_loss: 0.0559 - lr: 0.1000
# Epoch 296/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0600 - val_loss: 0.0559 - lr: 0.1000
# Epoch 297/1000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0600 - val_loss: 0.0558 - lr: 0.1000
# Epoch 298/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0599 - val_loss: 0.0558 - lr: 0.1000
# Epoch 299/1000
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0599 - val_loss: 0.0558 - lr: 0.1000
# Epoch 300/1000
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0598 - val_loss: 0.0557 - lr: 0.1000
# Epoch 301/1000
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0598 - val_loss: 0.0557 - lr: 0.1000
# Epoch 302/1000
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0597 - val_loss: 0.0557 - lr: 0.1000
# Epoch 303/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0597 - val_loss: 0.0556 - lr: 0.1000
# Epoch 304/1000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0597 - val_loss: 0.0556 - lr: 0.1000
# Epoch 305/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0596 - val_loss: 0.0556 - lr: 0.1000
# Epoch 306/1000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0596 - val_loss: 0.0556 - lr: 0.1000
# Epoch 307/1000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0596 - val_loss: 0.0555 - lr: 0.1000
# Epoch 308/1000
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0595 - val_loss: 0.0555 - lr: 0.1000
# Epoch 309/1000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0595 - val_loss: 0.0555 - lr: 0.1000
# Epoch 310/1000
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0594 - val_loss: 0.0555 - lr: 0.1000
# Epoch 311/1000
# 1/1 [==============================] - 0s 156ms/step - loss: 0.0594 - val_loss: 0.0554 - lr: 0.1000
# Epoch 312/1000
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0594 - val_loss: 0.0554 - lr: 0.1000
# Epoch 313/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0593 - val_loss: 0.0554 - lr: 0.1000
# Epoch 314/1000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0593 - val_loss: 0.0554 - lr: 0.1000
# Epoch 315/1000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0593 - val_loss: 0.0553 - lr: 0.1000
# Epoch 316/1000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0592 - val_loss: 0.0553 - lr: 0.1000
# Epoch 317/1000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0592 - val_loss: 0.0553 - lr: 0.1000
# Epoch 318/1000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0592 - val_loss: 0.0553 - lr: 0.1000
# Epoch 319/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0592 - val_loss: 0.0553 - lr: 0.1000
# Epoch 320/1000
# 1/1 [==============================] - 0s 231ms/step - loss: 0.0591 - val_loss: 0.0552 - lr: 0.1000
# Epoch 321/1000
# 1/1 [==============================] - 0s 221ms/step - loss: 0.0591 - val_loss: 0.0552 - lr: 0.1000
# Epoch 322/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0591 - val_loss: 0.0552 - lr: 0.1000
# Epoch 323/1000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0590 - val_loss: 0.0552 - lr: 0.1000
# Epoch 324/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0590 - val_loss: 0.0552 - lr: 0.1000
# Epoch 325/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0590 - val_loss: 0.0551 - lr: 0.1000
# Epoch 326/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0590 - val_loss: 0.0551 - lr: 0.1000
# Epoch 327/1000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0589 - val_loss: 0.0551 - lr: 0.1000
# Epoch 328/1000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0589 - val_loss: 0.0551 - lr: 0.1000
# Epoch 329/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0589 - val_loss: 0.0551 - lr: 0.1000
# Epoch 330/1000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0589 - val_loss: 0.0551 - lr: 0.1000
# Epoch 331/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0588 - val_loss: 0.0550 - lr: 0.1000
# Epoch 332/1000
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0588 - val_loss: 0.0550 - lr: 0.1000
# Epoch 333/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0588 - val_loss: 0.0550 - lr: 0.1000
# Epoch 334/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0588 - val_loss: 0.0550 - lr: 0.1000
# Epoch 335/1000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0587 - val_loss: 0.0550 - lr: 0.1000
# Epoch 336/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0587 - val_loss: 0.0550 - lr: 0.1000
# Epoch 337/1000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0587 - val_loss: 0.0550 - lr: 0.1000
# Epoch 338/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0587 - val_loss: 0.0549 - lr: 0.1000
# Epoch 339/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0587 - val_loss: 0.0549 - lr: 0.1000
# Epoch 340/1000
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0586 - val_loss: 0.0549 - lr: 0.1000
# Epoch 341/1000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0586 - val_loss: 0.0549 - lr: 0.1000
# Epoch 342/1000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0586 - val_loss: 0.0549 - lr: 0.1000
# Epoch 343/1000
# 1/1 [==============================] - 0s 166ms/step - loss: 0.0586 - val_loss: 0.0549 - lr: 0.1000
# Epoch 344/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0586 - val_loss: 0.0549 - lr: 0.1000
# Epoch 345/1000
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0585 - val_loss: 0.0549 - lr: 0.1000
# Epoch 346/1000
# 1/1 [==============================] - 0s 148ms/step - loss: 0.0585 - val_loss: 0.0548 - lr: 0.1000
# Epoch 347/1000
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0585 - val_loss: 0.0548 - lr: 0.1000
# Epoch 348/1000
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0585 - val_loss: 0.0548 - lr: 0.1000
# Epoch 349/1000
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0585 - val_loss: 0.0548 - lr: 0.1000
# Epoch 350/1000
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0585 - val_loss: 0.0548 - lr: 0.1000
# Epoch 351/1000
# 1/1 [==============================] - 0s 139ms/step - loss: 0.0584 - val_loss: 0.0548 - lr: 0.1000
# Epoch 352/1000
# 1/1 [==============================] - 0s 188ms/step - loss: 0.0584 - val_loss: 0.0548 - lr: 0.1000
# Epoch 353/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0584 - val_loss: 0.0548 - lr: 0.1000
# Epoch 354/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0584 - val_loss: 0.0548 - lr: 0.1000
# Epoch 355/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0584 - val_loss: 0.0548 - lr: 0.1000
# Epoch 356/1000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0584 - val_loss: 0.0547 - lr: 0.1000
# Epoch 357/1000
# 1/1 [==============================] - 0s 302ms/step - loss: 0.0583 - val_loss: 0.0547 - lr: 0.1000
# Epoch 358/1000
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0583 - val_loss: 0.0547 - lr: 0.1000
# Epoch 359/1000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0583 - val_loss: 0.0547 - lr: 0.1000
# Epoch 360/1000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0583 - val_loss: 0.0547 - lr: 0.1000
# Epoch 361/1000
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0583 - val_loss: 0.0547 - lr: 0.1000
# Epoch 362/1000
# 1/1 [==============================] - 0s 150ms/step - loss: 0.0583 - val_loss: 0.0547 - lr: 0.1000
# Epoch 363/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0582 - val_loss: 0.0547 - lr: 0.1000
# Epoch 364/1000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0582 - val_loss: 0.0547 - lr: 0.1000
# Epoch 365/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0582 - val_loss: 0.0547 - lr: 0.1000
# Epoch 366/1000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0582 - val_loss: 0.0547 - lr: 0.1000
# Epoch 367/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0582 - val_loss: 0.0546 - lr: 0.1000
# Epoch 368/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0582 - val_loss: 0.0546 - lr: 0.1000
# Epoch 369/1000
# 1/1 [==============================] - 0s 200ms/step - loss: 0.0582 - val_loss: 0.0546 - lr: 0.1000
# Epoch 370/1000
# 1/1 [==============================] - 0s 149ms/step - loss: 0.0581 - val_loss: 0.0546 - lr: 0.1000
# Epoch 371/1000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0581 - val_loss: 0.0546 - lr: 0.1000
# Epoch 372/1000
# 1/1 [==============================] - 0s 199ms/step - loss: 0.0581 - val_loss: 0.0546 - lr: 0.1000
# Epoch 373/1000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0581 - val_loss: 0.0546 - lr: 0.1000
# Epoch 374/1000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0581 - val_loss: 0.0546 - lr: 0.1000
# Epoch 375/1000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0581 - val_loss: 0.0546 - lr: 0.1000
# Epoch 376/1000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0581 - val_loss: 0.0546 - lr: 0.1000
# Epoch 377/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0581 - val_loss: 0.0546 - lr: 0.1000
# Epoch 378/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0580 - val_loss: 0.0546 - lr: 0.1000
# Epoch 379/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0580 - val_loss: 0.0545 - lr: 0.1000
# Epoch 380/1000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0580 - val_loss: 0.0545 - lr: 0.1000
# Epoch 381/1000
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0580 - val_loss: 0.0545 - lr: 0.1000
# Epoch 382/1000
# 1/1 [==============================] - 0s 239ms/step - loss: 0.0580 - val_loss: 0.0545 - lr: 0.1000
# Epoch 383/1000
# 1/1 [==============================] - 0s 227ms/step - loss: 0.0580 - val_loss: 0.0545 - lr: 0.1000
# Epoch 384/1000
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0580 - val_loss: 0.0545 - lr: 0.1000
# Epoch 385/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0580 - val_loss: 0.0545 - lr: 0.1000
# Epoch 386/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0579 - val_loss: 0.0545 - lr: 0.1000
# Epoch 387/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0579 - val_loss: 0.0545 - lr: 0.1000
# Epoch 388/1000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0579 - val_loss: 0.0545 - lr: 0.1000
# Epoch 389/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0579 - val_loss: 0.0545 - lr: 0.1000
# Epoch 390/1000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0579 - val_loss: 0.0545 - lr: 0.1000
# Epoch 391/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0579 - val_loss: 0.0544 - lr: 0.1000
# Epoch 392/1000
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0579 - val_loss: 0.0544 - lr: 0.1000
# Epoch 393/1000
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0579 - val_loss: 0.0544 - lr: 0.1000
# Epoch 394/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0578 - val_loss: 0.0544 - lr: 0.1000
# Epoch 395/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0578 - val_loss: 0.0544 - lr: 0.1000
# Epoch 396/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0578 - val_loss: 0.0544 - lr: 0.1000
# Epoch 397/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0578 - val_loss: 0.0544 - lr: 0.1000
# Epoch 398/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0578 - val_loss: 0.0544 - lr: 0.1000
# Epoch 399/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0578 - val_loss: 0.0544 - lr: 0.1000
# Epoch 400/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0578 - val_loss: 0.0544 - lr: 0.1000
# Epoch 401/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0578 - val_loss: 0.0544 - lr: 0.1000
# Epoch 402/1000
# 1/1 [==============================] - 0s 335ms/step - loss: 0.0578 - val_loss: 0.0544 - lr: 0.1000
# Epoch 403/1000
# 1/1 [==============================] - 0s 157ms/step - loss: 0.0577 - val_loss: 0.0543 - lr: 0.1000
# Epoch 404/1000
# 1/1 [==============================] - 0s 145ms/step - loss: 0.0577 - val_loss: 0.0543 - lr: 0.1000
# Epoch 405/1000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0577 - val_loss: 0.0543 - lr: 0.1000
# Epoch 406/1000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0577 - val_loss: 0.0543 - lr: 0.1000
# Epoch 407/1000
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0577 - val_loss: 0.0543 - lr: 0.1000
# Epoch 408/1000
# 1/1 [==============================] - 0s 194ms/step - loss: 0.0577 - val_loss: 0.0543 - lr: 0.1000
# Epoch 409/1000
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0577 - val_loss: 0.0543 - lr: 0.1000
# Epoch 410/1000
# 1/1 [==============================] - 0s 210ms/step - loss: 0.0577 - val_loss: 0.0543 - lr: 0.1000
# Epoch 411/1000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0576 - val_loss: 0.0543 - lr: 0.1000
# Epoch 412/1000
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0576 - val_loss: 0.0543 - lr: 0.1000
# Epoch 413/1000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0576 - val_loss: 0.0543 - lr: 0.1000
# Epoch 414/1000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0576 - val_loss: 0.0542 - lr: 0.1000
# Epoch 415/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0576 - val_loss: 0.0542 - lr: 0.1000
# Epoch 416/1000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0576 - val_loss: 0.0542 - lr: 0.1000
# Epoch 417/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0576 - val_loss: 0.0542 - lr: 0.1000
# Epoch 418/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0576 - val_loss: 0.0542 - lr: 0.1000
# Epoch 419/1000
# 1/1 [==============================] - 0s 179ms/step - loss: 0.0576 - val_loss: 0.0542 - lr: 0.1000
# Epoch 420/1000
# ...
# Epoch 863/1000
# 1/1 [==============================] - 0s 338ms/step - loss: 0.0658 - val_loss: 0.0606 - lr: 0.0900
# Epoch 864/1000
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0652 - val_loss: 0.0602 - lr: 0.0900
# Epoch 865/1000
# 1/1 [==============================] - 0s 251ms/step - loss: 0.0638 - val_loss: 0.0587 - lr: 0.0900
# Epoch 866/1000
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0632 - val_loss: 0.0585 - lr: 0.0900
# Epoch 867/1000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0621 - val_loss: 0.0571 - lr: 0.0900
# Epoch 868/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0615 - val_loss: 0.0570 - lr: 0.0900
# Epoch 869/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0606 - val_loss: 0.0557 - lr: 0.0900
# Epoch 870/1000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0601 - val_loss: 0.0557 - lr: 0.0900
# Epoch 871/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0593 - val_loss: 0.0545 - lr: 0.0900
# Epoch 872/1000
# 1/1 [==============================] - 0s 316ms/step - loss: 0.0588 - val_loss: 0.0546 - lr: 0.0900
# Epoch 873/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0582 - val_loss: 0.0535 - lr: 0.0900
# Epoch 874/1000
# 1/1 [==============================] - 0s 139ms/step - loss: 0.0578 - val_loss: 0.0536 - lr: 0.0900
# Epoch 875/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0572
# Epoch 875: ReduceLROnPlateau reducing learning rate to 0.08100000321865082.
# 1/1 [==============================] - 0s 153ms/step - loss: 0.0572 - val_loss: 0.0526 - lr: 0.0900
# Epoch 876/1000
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0569 - val_loss: 0.0509 - lr: 0.0810
# Epoch 877/1000
# 1/1 [==============================] - 0s 147ms/step - loss: 0.0546 - val_loss: 0.0493 - lr: 0.0810
# Epoch 878/1000
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0533 - val_loss: 0.0488 - lr: 0.0810
# Epoch 879/1000
# 1/1 [==============================] - 0s 155ms/step - loss: 0.0525 - val_loss: 0.0481 - lr: 0.0810
# Epoch 880/1000
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0521 - val_loss: 0.0480 - lr: 0.0810
# Epoch 881/1000
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0518 - val_loss: 0.0477 - lr: 0.0810
# Epoch 882/1000
# 1/1 [==============================] - 1s 738ms/step - loss: 0.0516 - val_loss: 0.0477 - lr: 0.0810
# Epoch 883/1000
# 1/1 [==============================] - 1s 506ms/step - loss: 0.0515 - val_loss: 0.0475 - lr: 0.0810
# Epoch 884/1000
# 1/1 [==============================] - 0s 252ms/step - loss: 0.0514 - val_loss: 0.0476 - lr: 0.0810
# Epoch 885/1000
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0513 - val_loss: 0.0474 - lr: 0.0810
# Epoch 886/1000
# 1/1 [==============================] - 0s 188ms/step - loss: 0.0513 - val_loss: 0.0475 - lr: 0.0810
# Epoch 887/1000
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0513 - val_loss: 0.0474 - lr: 0.0810
# Epoch 888/1000
# 1/1 [==============================] - 0s 188ms/step - loss: 0.0513 - val_loss: 0.0474 - lr: 0.0810
# Epoch 889/1000
# 1/1 [==============================] - 0s 248ms/step - loss: 0.0512 - val_loss: 0.0474 - lr: 0.0810
# Epoch 890/1000
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0512 - val_loss: 0.0474 - lr: 0.0810
# Epoch 891/1000
# 1/1 [==============================] - 0s 210ms/step - loss: 0.0512 - val_loss: 0.0474 - lr: 0.0810
# Epoch 892/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0512 - val_loss: 0.0474 - lr: 0.0810
# Epoch 893/1000
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0512 - val_loss: 0.0474 - lr: 0.0810
# Epoch 894/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0512 - val_loss: 0.0474 - lr: 0.0810
# Epoch 895/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0512 - val_loss: 0.0473 - lr: 0.0810
# Epoch 896/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0512 - val_loss: 0.0473 - lr: 0.0810
# Epoch 897/1000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0512 - val_loss: 0.0473 - lr: 0.0810
# Epoch 898/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0512 - val_loss: 0.0473 - lr: 0.0810
# Epoch 899/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0512 - val_loss: 0.0473 - lr: 0.0810
# Epoch 900/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0511 - val_loss: 0.0473 - lr: 0.0810
# Epoch 901/1000
# 1/1 [==============================] - 0s 243ms/step - loss: 0.0511 - val_loss: 0.0473 - lr: 0.0810
# Epoch 902/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0511 - val_loss: 0.0473 - lr: 0.0810
# Epoch 903/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0511 - val_loss: 0.0473 - lr: 0.0810
# Epoch 904/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0511 - val_loss: 0.0473 - lr: 0.0810
# Epoch 905/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0511 - val_loss: 0.0473 - lr: 0.0810
# Epoch 906/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0511 - val_loss: 0.0472 - lr: 0.0810
# Epoch 907/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0511 - val_loss: 0.0472 - lr: 0.0810
# Epoch 908/1000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0511 - val_loss: 0.0472 - lr: 0.0810
# Epoch 909/1000
# 1/1 [==============================] - 0s 215ms/step - loss: 0.0511 - val_loss: 0.0472 - lr: 0.0810
# Epoch 910/1000
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0511 - val_loss: 0.0472 - lr: 0.0810
# Epoch 911/1000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0511 - val_loss: 0.0472 - lr: 0.0810
# Epoch 912/1000
# 1/1 [==============================] - 0s 158ms/step - loss: 0.0511 - val_loss: 0.0472 - lr: 0.0810
# Epoch 913/1000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0510 - val_loss: 0.0472 - lr: 0.0810
# Epoch 914/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0510 - val_loss: 0.0472 - lr: 0.0810
# Epoch 915/1000
# 1/1 [==============================] - 0s 195ms/step - loss: 0.0510 - val_loss: 0.0472 - lr: 0.0810
# Epoch 916/1000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0510 - val_loss: 0.0472 - lr: 0.0810
# Epoch 917/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0510 - val_loss: 0.0472 - lr: 0.0810
# Epoch 918/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0510 - val_loss: 0.0472 - lr: 0.0810
# Epoch 919/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0510 - val_loss: 0.0471 - lr: 0.0810
# Epoch 920/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0510 - val_loss: 0.0471 - lr: 0.0810
# Epoch 921/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0510 - val_loss: 0.0471 - lr: 0.0810
# Epoch 922/1000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0510 - val_loss: 0.0471 - lr: 0.0810
# Epoch 923/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0510 - val_loss: 0.0471 - lr: 0.0810
# Epoch 924/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0510 - val_loss: 0.0471 - lr: 0.0810
# Epoch 925/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0510 - val_loss: 0.0471 - lr: 0.0810
# Epoch 926/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0509 - val_loss: 0.0471 - lr: 0.0810
# Epoch 927/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0509 - val_loss: 0.0471 - lr: 0.0810
# Epoch 928/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0509 - val_loss: 0.0471 - lr: 0.0810
# Epoch 929/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0509 - val_loss: 0.0471 - lr: 0.0810
# Epoch 930/1000
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0509 - val_loss: 0.0471 - lr: 0.0810
# Epoch 931/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0509 - val_loss: 0.0471 - lr: 0.0810
# Epoch 932/1000
# 1/1 [==============================] - 0s 139ms/step - loss: 0.0509 - val_loss: 0.0470 - lr: 0.0810
# Epoch 933/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0509 - val_loss: 0.0470 - lr: 0.0810
# Epoch 934/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0509 - val_loss: 0.0470 - lr: 0.0810
# Epoch 935/1000
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0509 - val_loss: 0.0470 - lr: 0.0810
# Epoch 936/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0509 - val_loss: 0.0470 - lr: 0.0810
# Epoch 937/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0509 - val_loss: 0.0470 - lr: 0.0810
# Epoch 938/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0509 - val_loss: 0.0470 - lr: 0.0810
# Epoch 939/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0509 - val_loss: 0.0470 - lr: 0.0810
# Epoch 940/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0508 - val_loss: 0.0470 - lr: 0.0810
# Epoch 941/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0508 - val_loss: 0.0470 - lr: 0.0810
# Epoch 942/1000
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0508 - val_loss: 0.0470 - lr: 0.0810
# Epoch 943/1000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0508 - val_loss: 0.0470 - lr: 0.0810
# Epoch 944/1000
# 1/1 [==============================] - 0s 171ms/step - loss: 0.0508 - val_loss: 0.0470 - lr: 0.0810
# Epoch 945/1000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0508 - val_loss: 0.0470 - lr: 0.0810
# Epoch 946/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0508 - val_loss: 0.0469 - lr: 0.0810
# Epoch 947/1000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0508 - val_loss: 0.0469 - lr: 0.0810
# Epoch 948/1000
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0508 - val_loss: 0.0469 - lr: 0.0810
# Epoch 949/1000
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0508 - val_loss: 0.0469 - lr: 0.0810
# Epoch 950/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0508 - val_loss: 0.0469 - lr: 0.0810
# Epoch 951/1000
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0508 - val_loss: 0.0469 - lr: 0.0810
# Epoch 952/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0508 - val_loss: 0.0469 - lr: 0.0810
# Epoch 953/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0508 - val_loss: 0.0469 - lr: 0.0810
# Epoch 954/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0507 - val_loss: 0.0469 - lr: 0.0810
# Epoch 955/1000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0507 - val_loss: 0.0469 - lr: 0.0810
# Epoch 956/1000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0507 - val_loss: 0.0469 - lr: 0.0810
# Epoch 957/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0507 - val_loss: 0.0469 - lr: 0.0810
# Epoch 958/1000
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0507 - val_loss: 0.0469 - lr: 0.0810
# Epoch 959/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0507 - val_loss: 0.0469 - lr: 0.0810
# Epoch 960/1000
# 1/1 [==============================] - 0s 191ms/step - loss: 0.0507 - val_loss: 0.0469 - lr: 0.0810
# Epoch 961/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0507 - val_loss: 0.0468 - lr: 0.0810
# Epoch 962/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0507 - val_loss: 0.0468 - lr: 0.0810
# Epoch 963/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0507 - val_loss: 0.0468 - lr: 0.0810
# Epoch 964/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0507 - val_loss: 0.0468 - lr: 0.0810
# Epoch 965/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0507 - val_loss: 0.0468 - lr: 0.0810
# Epoch 966/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0507 - val_loss: 0.0468 - lr: 0.0810
# Epoch 967/1000
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0507 - val_loss: 0.0468 - lr: 0.0810
# Epoch 968/1000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0507 - val_loss: 0.0468 - lr: 0.0810
# Epoch 969/1000
# 1/1 [==============================] - 0s 210ms/step - loss: 0.0506 - val_loss: 0.0468 - lr: 0.0810
# Epoch 970/1000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0506 - val_loss: 0.0468 - lr: 0.0810
# Epoch 971/1000
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0506 - val_loss: 0.0468 - lr: 0.0810
# Epoch 972/1000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0506 - val_loss: 0.0468 - lr: 0.0810
# Epoch 973/1000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0506 - val_loss: 0.0468 - lr: 0.0810
# Epoch 974/1000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0506 - val_loss: 0.0468 - lr: 0.0810
# Epoch 975/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0506 - val_loss: 0.0468 - lr: 0.0810
# Epoch 976/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0506 - val_loss: 0.0467 - lr: 0.0810
# Epoch 977/1000
# 1/1 [==============================] - 0s 198ms/step - loss: 0.0506 - val_loss: 0.0467 - lr: 0.0810
# Epoch 978/1000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0506 - val_loss: 0.0467 - lr: 0.0810
# Epoch 979/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0506 - val_loss: 0.0467 - lr: 0.0810
# Epoch 980/1000
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0506 - val_loss: 0.0467 - lr: 0.0810
# Epoch 981/1000
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0506 - val_loss: 0.0467 - lr: 0.0810
# Epoch 982/1000
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0506 - val_loss: 0.0467 - lr: 0.0810
# Epoch 983/1000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0506 - val_loss: 0.0467 - lr: 0.0810
# Epoch 984/1000
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0506 - val_loss: 0.0467 - lr: 0.0810
# Epoch 985/1000
# 1/1 [==============================] - 0s 170ms/step - loss: 0.0505 - val_loss: 0.0467 - lr: 0.0810
# Epoch 986/1000
# 1/1 [==============================] - 0s 179ms/step - loss: 0.0505 - val_loss: 0.0467 - lr: 0.0810
# Epoch 987/1000
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0505 - val_loss: 0.0467 - lr: 0.0810
# Epoch 988/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0505 - val_loss: 0.0467 - lr: 0.0810
# Epoch 989/1000
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0505 - val_loss: 0.0467 - lr: 0.0810
# Epoch 990/1000
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0505 - val_loss: 0.0467 - lr: 0.0810
# Epoch 991/1000
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0505 - val_loss: 0.0467 - lr: 0.0810
# Epoch 992/1000
# 1/1 [==============================] - 0s 142ms/step - loss: 0.0505 - val_loss: 0.0466 - lr: 0.0810
# Epoch 993/1000
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0505 - val_loss: 0.0466 - lr: 0.0810
# Epoch 994/1000
# 1/1 [==============================] - 0s 92ms/step - loss: 0.0505 - val_loss: 0.0466 - lr: 0.0810
# Epoch 995/1000
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0505 - val_loss: 0.0466 - lr: 0.0810
# Epoch 996/1000
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0505 - val_loss: 0.0466 - lr: 0.0810
# Epoch 997/1000
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0505 - val_loss: 0.0466 - lr: 0.0810
# Epoch 998/1000
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0505 - val_loss: 0.0466 - lr: 0.0810
# Epoch 999/1000
# 1/1 [==============================] - 0s 165ms/step - loss: 0.0505 - val_loss: 0.0466 - lr: 0.0810
# Epoch 1000/1000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0505 - val_loss: 0.0466 - lr: 0.0810

# %% [markdown]
# ## Test

# %%
import plotly.graph_objects as go


layout = go.Layout(width=800, height=600)
x1_nn_train_pred = model_x1.predict([X_train[:, :2]])
fig3 = go.Figure(data=go.Scatter3d(x=X_train[:, 0], y=X_train[:, 1], z=x1_nn_train_pred[:,0],
                                   mode='markers', marker=dict(size=5), name='train'), layout=layout)

x1_nn_test_pred = model_x1.predict([X_test[:, :2]])
fig3.add_trace(go.Scatter3d(x=X_test[:, 0], y=X_test[:, 1], z=x1_nn_test_pred[:,0],
                            mode='markers', marker=dict(size=5), name='test'))
fig3.show()

layout = go.Layout(width=800, height=600)
X1_mesh, X2_mesh = np.meshgrid(np.linspace(-1, 1, 20), np.linspace(-1, 1, 20))
x1_mesh, x2_mesh = np.ravel(X1_mesh).reshape((-1, 1)), np.ravel(X2_mesh).reshape((-1, 1))
X1_mesh = np.hstack((x1_mesh, x2_mesh))
y_mesh = model_x1.predict([X1_mesh])
fig4 = go.Figure(data=go.Scatter3d(x=x1_mesh.ravel(), y=x2_mesh.ravel(), z=y_mesh.ravel(),
                                   mode='markers', marker=dict(size=5)), layout=layout)
fig4.show()

layout = go.Layout(width=800, height=600)
X1_mesh, X2_mesh = np.meshgrid(np.linspace(-1, 1, 20), np.linspace(-1, 1, 20))
x1_mesh, x2_mesh = np.ravel(X1_mesh).reshape((-1, 1)), np.ravel(X2_mesh).reshape((-1, 1))
X1_mesh = np.hstack((x1_mesh, x2_mesh))
y_mesh = model_x1.predict([X1_mesh])
X1_mesh_actual = scaler_X.inverse_transform(X1_mesh)
fig4 = go.Figure(data=go.Scatter3d(x=X1_mesh_actual[:, 0], 
                                   y=X1_mesh_actual[:, 1], z=y_mesh.ravel(),
                                   mode='markers', marker=dict(size=5)), layout=layout)
fig4.show()
# Out:
# 83/83 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 0s/step
# 13/13 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 3ms/step

# %%
accs_plot = np.linspace(0, 2.5, 5)[::-1]
speeds_plot = np.linspace(0, 5, 20)
fig, ax = plt.subplots(1, 1, figsize=(7,2.5), sharex='col')
markers = ['.', 'o', '^', '*', 'v']
for acc, marker in zip(accs_plot, markers):
    X_test_speed = np.hstack((speeds_plot.reshape((-1, 1)), np.zeros((speeds_plot.shape[0], 1)) + acc))
    ax.plot(speeds_plot, model_x1.predict(scaler_X.transform(X_test_speed)), label=f'rms acc. = {acc}',
            color=plt.rcParams['axes.prop_cycle'].by_key()['color'][1], marker=marker)
ax.set_xlabel(r'$v$ (m/s)')
ax.set_ylabel(r'$f(x)$')
ax.set_xlim((0,5))
# ax.set_ylim((0,.01))
ax.minorticks_on()
ax.legend()
# Out:
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step

# %% [markdown]
# ## Robustness testing

# %%
X_equal_actual = np.array([features_lf_1.loc[:, 'speed'].values, features_lf_1.loc[:, 'z_rolling_rms'].values, 
              features_lf_2_matched.loc[:, 'speed'].values, features_lf_2_matched.loc[:, 'z_rolling_rms'].values]).T
y_equal = np.zeros((X_equal.shape[0], 1))

X_equal = np.hstack((scaler_X.transform(X_equal_actual[:, :2]), scaler_X.transform(X_equal_actual[:, 2:])))

x1_1_pred = model_x1.predict([X_equal[:, :2]])
x1_2_pred = model_x1.predict([X_equal[:, 2:]])


fig, ax = plt.subplots(3, 1, figsize=(7,7), sharex='col')
ax_twin = []
for i, _ in enumerate(ax):
    _.minorticks_on()
    if i <= 1:
        ax_twin.append(_.twinx())
        ax_twin[-1].minorticks_on()

ax_twin[0].plot(X_equal[:, 0], color='blue', linestyle='-', linewidth=0.75)
ax_twin[0].plot(X_equal[:, 2], color='red', linestyle='-', linewidth=0.75)
ax[0].plot(X_equal_actual[:, 0], color='blue', label='pass_1', linewidth=0.75)
ax[0].plot(X_equal_actual[:, 2], color='red', label='pass_2', linewidth=0.75)
ax[0].set_ylabel('speed (m/s)')
ax_twin[0].set_ylabel('normalized speed')
ax[0].legend()
ax_twin[1].plot(X_equal[:, 1], color='blue', linestyle='-', linewidth=0.75)
ax_twin[1].plot(X_equal[:, 3], color='red', linestyle='-', linewidth=0.75)
ax[1].plot(X_equal_actual[:, 1], color='blue', linestyle='-', label='pass_1', linewidth=0.75)
ax[1].plot(X_equal_actual[:, 3], color='red', linestyle='-', label='pass_2', linewidth=0.75)
ax[1].fill_between(np.linspace(0,x1_1_pred.shape[0]-1,x1_1_pred.shape[0]), 
                   (X_equal_actual[:, 1]).ravel(), 
                   (X_equal_actual[:, 3]).ravel(), 
                   color='grey', alpha=0.3)  # Adjust alpha for transparency if needed
ax[1].set_ylabel(r'rms acc. (m/s$^2$)')
ax_twin[1].set_ylabel('normalized rms acc.')
ax[1].legend()
ax[2].plot(x1_1_pred, color='blue', linestyle='-', label='pass_1', linewidth=0.75)
ax[2].plot(x1_2_pred, color='red', linestyle='-', label='pass_2', linewidth=0.75)
ax[2].fill_between(np.linspace(0,x1_1_pred.shape[0]-1,x1_1_pred.shape[0]), 
                   (x1_1_pred).ravel(), 
                   (x1_2_pred).ravel(), 
                   color='grey', alpha=0.3)  # Adjust alpha for transparency if needed
ax[2].set_ylabel(r'$f(x)$')
ax[2].legend()
ax[2].set_xlabel('sample')


reference_path = r'C:\Users\joses\Mi unidad\TRABAJO\49_profile_estimation\TRABAJO\car_models\synthetic_dataset\four_ramps_cwl_slow_cs'
i_ini, i_fin = 2, 150 # s
acc_orig_df_reference_20 = pd.read_csv(path.join(reference_path, "0/AccelerometerUncalibrated.csv")).iloc[i_ini*fs_acc:i_fin*fs_acc, :].reset_index()
loc_orig_df_reference_20 = pd.read_csv(path.join(reference_path, "0/Location.csv")).iloc[i_ini:i_fin, :].reset_index()
loc_orig_df_reference_20 = loc_orig_df_reference_20.loc[loc_orig_df_reference_20['speed'] > speed_stopped_th].reset_index()
acc_feat_df_reference_20 = rolling_rms(acc_orig_df_reference_20)
acc_orig_df_reference_30 = pd.read_csv(path.join(reference_path, "1/AccelerometerUncalibrated.csv")).iloc[i_ini*fs_acc:i_fin*fs_acc, :].reset_index()
loc_orig_df_reference_30 = pd.read_csv(path.join(reference_path, "1/Location.csv")).iloc[i_ini:i_fin, :].reset_index()
loc_orig_df_reference_30 = loc_orig_df_reference_30.loc[loc_orig_df_reference_30['speed'] > speed_stopped_th].reset_index()
acc_feat_df_reference_30 = rolling_rms(acc_orig_df_reference_30)

features_lf_reference_20, features_lf_reference_30 = calc_features_lf_n(loc_orig_df_reference_20, acc_feat_df_reference_20), calc_features_lf_n(loc_orig_df_reference_30, acc_feat_df_reference_30)

time_matches_dict_reference_20, loc_orig_df_reference_20_matched, features_lf_reference_20_matched = times_matches_1_n(loc_orig_df_1, loc_orig_df_reference_20, features_lf_reference_20)
time_matches_dict_reference_30, loc_orig_df_reference_30_matched, features_lf_reference_30_matched = times_matches_1_n(loc_orig_df_1, loc_orig_df_reference_30, features_lf_reference_30)

scale_20 = {'min': np.min(features_lf_reference_20_matched['z_rolling_rms'][50:100]), 
            'max': np.max(features_lf_reference_20_matched['z_rolling_rms'][50:100])}
scale_30 = {'min': np.min(features_lf_reference_30_matched['z_rolling_rms'][50:100]), 
            'max': np.max(features_lf_reference_30_matched['z_rolling_rms'][50:100])}

ax_twin.append(ax[2].twinx())
ax_twin[2].plot(((features_lf_reference_20_matched['z_rolling_rms']-scale_20['min'])*\
           (np.max(x1_1_pred)-np.min(x1_1_pred))/(scale_20['max']-scale_20['min']))+np.min(x1_1_pred),
           color='cyan', label='ref_pass_1 20 m/s')
ax_twin[2].plot(((features_lf_reference_30_matched['z_rolling_rms']-scale_30['min'])*\
           (np.max(x1_2_pred)-np.min(x1_2_pred))/(scale_30['max']-scale_30['min']))+np.min(x1_2_pred),
                color='pink', label='ref_pass_2 30 m/s')
ax_twin[2].set_ylabel(r'reference of $f(x)$')
ax_twin[2].set_ylim(ax[2].get_ylim())
ax_twin[2].legend()
# Out:
# 78/78 [==============================] - 0s 2ms/step
# 78/78 [==============================] - 0s 4ms/step

# %%
circ_rad = 10

# Create a map centered at the mean latitude and longitude of loc_orig_df_2
center_lat = loc_orig_df_1['latitude'].mean()
center_lon = loc_orig_df_1['longitude'].mean()
mymap = folium.Map(location=[center_lat, center_lon], zoom_start=10, tiles='OpenStreetMap')

f1, f2 = x1_1_pred[:,0], x1_2_pred[:,0]
f1, f2 = f1-np.min(f1), f2-np.min(f2)
f1, f2 = f1/np.max(f1), f2/np.max(f2)

# Plot the latitude and longitude data on the map
for index in range(loc_orig_df_1.shape[0]):
    row1, row2 = loc_orig_df_1.iloc[index,:], loc_orig_df_2_matched.iloc[index,:]
    folium.Circle([row1['latitude'], row1['longitude']],
                        radius=circ_rad*f1[index],
                        color='blue',
                        fill=False,
                        fill_color='blue').add_to(mymap)
    folium.Circle([row2['latitude'], row2['longitude']],
                        radius=circ_rad*f2[index],
                        color='red',
                        fill=False,
                        fill_color='red').add_to(mymap)

# Save the map to an HTML file
mymap.save("map_f.html")

# %%
circ_rad = 5

# Create a map centered at the mean latitude and longitude of loc_orig_df_2
center_lat = loc_orig_df_1['latitude'].mean()
center_lon = loc_orig_df_1['longitude'].mean()
mymap = folium.Map(location=[center_lat, center_lon], zoom_start=10, tiles='OpenStreetMap')

acc1, acc2 = X_equal[:, 1], X_equal[:, 3]
acc1, acc2 = acc1-np.min(acc1), acc2-np.min(acc2)
acc1, acc2 = acc1/np.max(acc1), acc2/np.max(acc2)

# Plot the latitude and longitude data on the map
for index in range(loc_orig_df_1.shape[0]):
    row1, row2 = loc_orig_df_1.iloc[index,:], loc_orig_df_2_matched.iloc[index,:]
    folium.Circle([row1['latitude'], row1['longitude']],
                        radius=circ_rad*acc1[index],
                        color='blue',
                        fill=False,
                        fill_color='blue').add_to(mymap)
    folium.Circle([row2['latitude'], row2['longitude']],
                        radius=circ_rad*acc2[index],
                        color='red',
                        fill=False,
                        fill_color='red').add_to(mymap)

# Save the map to an HTML file
mymap.save("map_acc.html")

# %% [markdown]
# ### Correlations

# %%
# acceleration correlation
fig, ax = plt.subplots(1, 2, figsize=(6, 3), sharex='all', sharey=all)
ax[0].plot(acc1, acc2, linestyle='', color='blue', marker='.', label=f'r={np.round(np.corrcoef(acc1, acc2)[1,0], 2)}')
ax[0].set_xlabel('acc_1')
ax[0].set_ylabel('acc_2')
ax[0].legend()
ax[1].plot(f1, f2, linestyle='', color='red', marker='.', label=f'r={np.round(np.corrcoef(f1, f2)[1,0], 2)}')
ax[1].set_xlabel('f_1')
ax[1].set_ylabel('f_2')
ax[1].legend()
plt.show()


# acceleration correlation
acc_low = np.vstack((acc1, acc2)).T
acc_low = acc_low[(acc_low[:, 0] < 0.5) & (acc_low[:, 1] < 0.5), :]
acc1_low, acc2_low = acc_low[:, 0], acc_low[:, 1]
f_low = np.vstack((f1, f2)).T
f_low = f_low[(f_low[:, 0] < 0.5) & (f_low[:, 1] < 0.5), :]
f1_low, f2_low = f_low[:, 0], f_low[:, 1]

fig, ax = plt.subplots(1, 2, figsize=(6, 3), sharex='all', sharey=all)
ax[0].plot(acc1_low, acc2_low, linestyle='', color='blue', marker='.', label=f'r={np.round(np.corrcoef(acc1_low, acc2_low)[1,0], 2)}')
ax[0].set_xlabel('acc_1')
ax[0].set_ylabel('acc_2')
ax[0].legend()
ax[1].plot(f1_low, f2_low, linestyle='', color='red', marker='.', label=f'r={np.round(np.corrcoef(f1_low, f2_low)[1,0], 2)}')
ax[1].set_xlabel('f_1')
ax[1].set_ylabel('f_2')
ax[1].legend()
