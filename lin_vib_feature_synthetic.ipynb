# %%
import pandas as pd
from os import path
import matplotlib.pyplot as plt
from scipy import signal, interpolate
import numpy as np
import folium

# %%
source_path = r"C:\Users\joses\Mi unidad\TRABAJO\49_profile_estimation\TRABAJO\car_models\synthetic_dataset\two_ramps"

win_len = 100

speed_stopped_th = .1 # m/s

# %% [markdown]
# # Data Extraction

# %%
subtract_g = False
fs_acc = 100 # sps

# Dataset 1
i_ini, i_fin = 10, 100 # s
acc_orig_df_1 = pd.read_csv(path.join(source_path, "0/AccelerometerUncalibrated.csv")).iloc[i_ini*fs_acc:i_fin*fs_acc, :].reset_index()
if subtract_g:
    acc_orig_df_1['z'] = acc_orig_df_1['z'] - 9.81
loc_orig_df_1 = pd.read_csv(path.join(source_path, "0/Location.csv")).iloc[i_ini:i_fin, :].reset_index()
loc_orig_df_1 = loc_orig_df_1.loc[loc_orig_df_1['speed'] > speed_stopped_th].reset_index()

# Dataset 2
i_ini, i_fin = 10, 100 # s
acc_orig_df_2 = pd.read_csv(path.join(source_path, "1/AccelerometerUncalibrated.csv")).iloc[i_ini*fs_acc:i_fin*fs_acc, :].reset_index()
if subtract_g:
    acc_orig_df_2['z'] = acc_orig_df_2['z'] - 9.81
loc_orig_df_2 = pd.read_csv(path.join(source_path, "1/Location.csv")).iloc[i_ini:i_fin, :].reset_index()
loc_orig_df_2 = loc_orig_df_2.loc[loc_orig_df_2['speed'] > speed_stopped_th].reset_index()

plt.plot(loc_orig_df_1['longitude'], loc_orig_df_1['latitude'], label='dataset_1')
plt.plot(loc_orig_df_2['longitude'], loc_orig_df_2['latitude'], label='dataset_2')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.legend()
plt.show()

# %% [markdown]
# ## Raw Visualization

# %%
fig, ax = plt.subplots(1, 2, sharey='row')
ax[0].plot(acc_orig_df_1['seconds_elapsed'], acc_orig_df_1['z'])
ax[0].plot(loc_orig_df_1['seconds_elapsed'], loc_orig_df_1['speed'])
ax[1].plot(acc_orig_df_2['seconds_elapsed'], acc_orig_df_2['z'])
ax[1].plot(loc_orig_df_2['seconds_elapsed'], loc_orig_df_2['speed'])

# %% [markdown]
# # Feature extraction

# %%
# def rms(arr):
#     return np.sqrt(np.mean(arr**2))

# acc_feat_df_1 = pd.DataFrame(data=np.vstack((acc_orig_df_1['seconds_elapsed'].values, acc_orig_df_1['z'].rolling(win_len).apply(rms).values)).T, 
#                              columns=['seconds_elapsed', 'z_rolling_rms']).fillna(0)
# acc_feat_df_1.reset_index(inplace=True)
# acc_feat_df_2 = pd.DataFrame(data=np.vstack((acc_orig_df_2['seconds_elapsed'].values, acc_orig_df_2['z'].rolling(win_len).apply(rms).values)).T, 
#                              columns=['seconds_elapsed', 'z_rolling_rms']).fillna(0)
# acc_feat_df_2.reset_index(inplace=True)

def rolling_rms(acc_orig_df):
    acc2_cum = np.cumsum(acc_orig_df['z']**2)
    acc_rms = np.zeros(acc_orig_df.shape[0])
    for i in range(acc_orig_df.shape[0]-win_len):
        acc_rms[i+win_len] = np.sqrt((acc2_cum[i+win_len] - acc2_cum[i])/win_len)
    acc_feat_df = pd.DataFrame(data=np.vstack((acc_orig_df['seconds_elapsed'].values, acc_rms)).T, 
                                columns=['seconds_elapsed', 'z_rolling_rms']).fillna(0)
    acc_feat_df.reset_index(inplace=True)
    return acc_feat_df

acc_feat_df_1, acc_feat_df_2 = rolling_rms(acc_orig_df_1), rolling_rms(acc_orig_df_2)

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 5), sharex='all', sharey='row')
ax[0,0].plot(loc_orig_df_1['seconds_elapsed'], loc_orig_df_1['speed'])
ax[1,0].plot(acc_orig_df_1['seconds_elapsed'], acc_orig_df_1['z'])
ax[1,0].plot(acc_feat_df_1['seconds_elapsed'], acc_feat_df_1['z_rolling_rms'])
# ax[1,0].set_xlim([0, 200])
ax[0,1].plot(loc_orig_df_2['seconds_elapsed'], loc_orig_df_2['speed'])
ax[1,1].plot(acc_orig_df_2['seconds_elapsed'], acc_orig_df_2['z'])
ax[1,1].plot(acc_feat_df_2['seconds_elapsed'], acc_feat_df_2['z_rolling_rms'])
# ax[1,1].set_xlim([0, 60])
plt.show()

# %% [markdown]
# ### Scatter analysis

# %% [markdown]
# #### Low frequency

# %%
features_lf_1 = loc_orig_df_1.loc[:,:]
features_lf_1['z_rolling_rms'] = np.interp(x=loc_orig_df_1['seconds_elapsed'], 
                                           xp=acc_feat_df_1['seconds_elapsed'].values-((win_len/fs_acc)/2), fp=acc_feat_df_1['z_rolling_rms'])
features_lf_1 = features_lf_1.drop(columns=['level_0']).reset_index()
features_lf_2 = loc_orig_df_2.loc[:,:]
features_lf_2['z_rolling_rms'] = np.interp(x=loc_orig_df_2['seconds_elapsed'], 
                                           xp=acc_feat_df_2['seconds_elapsed'].values-((win_len/fs_acc)/2), fp=acc_feat_df_2['z_rolling_rms'])
features_lf_2 = features_lf_2.drop(columns=['level_0']).reset_index()

fig, ax = plt.subplots(2, 2, figsize=(10, 5), sharex='all', sharey='row')
ax[0,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['speed'])
ax[0,0].set_ylabel('speed (m/s)')
ax[1,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['z_rolling_rms'])
# ax[1,1].set_ylabel('rms acc. (m/s$^2$)')
ax[0,1].plot(features_lf_2['seconds_elapsed'], features_lf_2['speed'])
# ax[0,1].set_ylabel('speed (m/s)')
ax[1,1].plot(features_lf_2['seconds_elapsed'], features_lf_2['z_rolling_rms'])
ax[1,0].set_ylabel('rms acc. (m/s$^2$)')
ax[1,0].set_xlabel('time (s)')
ax[1,1].set_xlabel('time (s)')

plt.show()

fig, ax = plt.subplots(1, 2, figsize=(10, 5), sharex='all', sharey='all')
ax[0].plot(features_lf_1['z_rolling_rms'], features_lf_1['speed'], linestyle='-', marker='.')
ax[0].set_xlabel('rms acc. (m/s$^2$)')
ax[0].set_ylabel('speed (m/s)')
ax[1].plot(features_lf_2['z_rolling_rms'], features_lf_2['speed'], linestyle='-', marker='.')
ax[1].set_xlabel('rms acc. (m/s$^2$)')
plt.show()

# %% [markdown]
# ### Location matching

# %%
from scipy.spatial.distance import cdist


# Extract coordinates as arrays
coords_orig = loc_orig_df_1[['latitude', 'longitude']].values
coords_dest = loc_orig_df_2[['latitude', 'longitude']].values

# Compute pairwise distances
distances = cdist(coords_orig, coords_dest, metric='euclidean')

# Find the nearest point for each origin point
nearest_indices = distances.argmin(axis=1)
nearest_distances = distances.min(axis=1)

# Build a dictionary of time matches
time_matches_dict = {}
for i, (dist, idx) in enumerate(zip(nearest_distances, nearest_indices)):
    orig_time = loc_orig_df_1.iloc[i]['seconds_elapsed']
    dest_time = loc_orig_df_2.iloc[idx]['seconds_elapsed']
    time_matches_dict[orig_time] = dest_time

# %%
# from geopy import distance


# # time matching
# time_matches_dict = {}
# for index, row in loc_orig_df_1.iterrows():
#     lat_lon = np.array([row['latitude'], row['longitude']])
#     min_dist = (np.inf, np.nan)
#     for index_, row_ in loc_orig_df_2.iterrows():
#         lat_lon_ = np.array([row_['latitude'], row_['longitude']])
#         if index != index_:
#             dist = distance.distance(lat_lon, lat_lon_).km
#             if dist < min_dist[0]:
#                 min_dist = (dist, row_['seconds_elapsed'])
#     time_matches_dict.update({row['seconds_elapsed']: min_dist[1]})

# %%
# location matching
loc_orig_df_2_matched = loc_orig_df_1.copy()
for index, row in loc_orig_df_1.iterrows():
    seconds_elapsed_1 = row['seconds_elapsed']
    if index == len(loc_orig_df_2_matched):
        break
    loc_orig_df_2_matched.iloc[index] = loc_orig_df_2.loc[loc_orig_df_2['seconds_elapsed'] == time_matches_dict[seconds_elapsed_1]].values[0]
    
fig, ax = plt.subplots(2, 2, figsize=(10, 6), sharey='row')
ax[0,0].plot(loc_orig_df_1['latitude'].values)
ax[0,0].plot(loc_orig_df_2['latitude'].values)
ax[1,0].plot(loc_orig_df_1['longitude'].values)
ax[1,0].plot(loc_orig_df_2['longitude'].values)


ax[0,1].plot(loc_orig_df_1['latitude'].values)
ax[0,1].plot(loc_orig_df_2_matched['latitude'].values)
ax[1,1].plot(loc_orig_df_1['longitude'].values)
ax[1,1].plot(loc_orig_df_2_matched['longitude'].values)

ax[0,0].set_ylabel('latitude (deg.)')
ax[1,0].set_ylabel('longitude (deg.)')
ax[1,0].set_xlabel('time (s)')
ax[1,1].set_xlabel('time (s)')
# Out:
# Text(0.5, 0, 'time (s)')

# %% [markdown]
# # Training

# %%
# feature matching
features_lf_2_matched = features_lf_1.copy()
for index, row in features_lf_1.iterrows():
    seconds_elapsed_1 = row['seconds_elapsed']
    features_lf_2_matched.iloc[index] = features_lf_2.loc[features_lf_2['seconds_elapsed'] == time_matches_dict[seconds_elapsed_1]].values[0]

fig, ax = plt.subplots(2, 2, figsize=(10, 5), sharex='col', sharey='row')
ax[0,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['speed'])
ax[0,0].set_ylabel('speed (m/s)')
ax[1,0].plot(features_lf_1['seconds_elapsed'], features_lf_1['z_rolling_rms'])
# ax[1,1].set_ylabel('rms acc. (m/s$^2$)')
ax[0,1].plot(features_lf_2_matched['seconds_elapsed'], features_lf_2_matched['speed'])
# ax[0,1].set_ylabel('speed (m/s)')
ax[1,1].plot(features_lf_2_matched['seconds_elapsed'], features_lf_2_matched['z_rolling_rms'])
ax[1,0].set_ylabel('rms acc. (m/s$^2$)')
plt.show()

fig, ax = plt.subplots(1, 2, figsize=(10, 5), sharex='all', sharey='all')
ax[0].plot(features_lf_1['z_rolling_rms'], features_lf_1['speed'], linestyle='-', marker='.')
ax[0].set_xlabel('rms acc. (m/s$^2$)')
ax[0].set_ylabel('speed (m/s)')
ax[1].plot(features_lf_2_matched['z_rolling_rms'], features_lf_2_matched['speed'], linestyle='-', marker='.')
ax[1].set_xlabel('rms acc. (m/s$^2$)')
plt.show()

# %% [markdown]
# ### Datasets

# %%
X_equal = np.array([features_lf_1.loc[:, 'speed'].values, features_lf_1.loc[:, 'z_rolling_rms'].values, 
                    features_lf_2_matched.loc[:, 'speed'].values, features_lf_2_matched.loc[:, 'z_rolling_rms'].values]).T
y_equal = np.zeros((X_equal.shape[0], 1))

fig, ax = plt.subplots(2, 1, figsize=(15,5))
ax[0].plot(X_equal[:, 0], color='blue', linestyle='-', label='speed_1')
ax[0].plot(X_equal[:, 2], color='red', linestyle='-', label='speed_2')
ax[0].legend()
ax[1].plot(X_equal[:, 1], color='blue', linestyle='-', label='acc_1')
ax[1].plot(X_equal[:, 3], color='red', linestyle='-', label='acc_2')
ax[1].set_xlabel('sample')
ax[1].legend()

# %% [markdown]
# #### Ordinal labels

# %%
from sklearn.model_selection import train_test_split

# %%
speed_tol = 1. # m/s
acc_tol = 1. # 1.2 # m/s2

grid_length = X_equal.shape[0]//2
speed_grid = np.random.uniform(min([min(X_equal[:,0]), min(X_equal[:,2])]), 1.5*max([max(X_equal[:,0]), max(X_equal[:,2])]), (grid_length,1))
vib_grid = np.random.uniform(min([min(X_equal[:,1]), min(X_equal[:,3])]), max([max(X_equal[:,1]), max(X_equal[:,3])]), (grid_length,1))
X_grid = np.hstack((speed_grid, vib_grid, speed_grid, vib_grid))

X_ordinal = []
y_ordinal = []
for x1 in X_grid[:, :2]:
    for x2 in X_grid[:, 2:]:
        if abs(x1[0] - x2[0]) < speed_tol:
            if x1[1] > x2[1] + acc_tol:
                X_ordinal.append(np.hstack((x1, x2)))
                y_ordinal.append(1.)
            elif x1[1] < x2[1] - acc_tol:
                X_ordinal.append(np.hstack((x1, x2)))
                y_ordinal.append(-1.)
X_ordinal = np.array(X_ordinal)
y_ordinal = np.array(y_ordinal).reshape((-1, 1))

X_ordinal, _, y_ordinal, _ = train_test_split(X_ordinal, y_ordinal, test_size=0.99, shuffle=True)


X = np.vstack((X_equal, X_ordinal))
y = np.vstack((y_equal, y_ordinal))
shuffler = np.arange(X.shape[0])
np.random.default_rng().shuffle(shuffler)
X = X[shuffler, :]
y = y[shuffler, :]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=True)

plt.hist(y_train)
plt.hist(y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 speed_tol = 1. # m/s
#       2 acc_tol = 1. # 1.2 # m/s2
# ----> 4 grid_length = X_equal.shape[0]//2
#       5 speed_grid = np.random.uniform(min([min(X_equal[:,0]), min(X_equal[:,2])]), 1.5*max([max(X_equal[:,0]), max(X_equal[:,2])]), (grid_length,1))
#       6 vib_grid = np.random.uniform(min([min(X_equal[:,1]), min(X_equal[:,3])]), max([max(X_equal[:,1]), max(X_equal[:,3])]), (grid_length,1))
#
# NameError: name 'X_equal' is not defined

# %% [markdown]
# ## Model definition

# %%
import keras


x1_nn_input = keras.layers.Input(shape=(2,))
x2_nn_input = keras.layers.Input(shape=(2,))

activation = 'tanh'
reg = 'l2'
dropout = 0.0
shared_layers = [keras.layers.Dense(8, activation=activation, kernel_regularizer=reg, bias_regularizer=reg, activity_regularizer=reg),
                 keras.layers.Dropout(dropout),
                 keras.layers.BatchNormalization(),
                 keras.layers.Dense(4, activation=activation, kernel_regularizer=reg, bias_regularizer=reg, activity_regularizer=reg),
                 keras.layers.Dropout(dropout),
                 keras.layers.BatchNormalization(),
                 keras.layers.Dense(1, activation='linear', kernel_regularizer=reg, bias_regularizer=reg, activity_regularizer=reg)]
layer_extract_speed = keras.layers.Lambda(lambda x: x[:, 0:1])
layer_extract_vib = keras.layers.Lambda(lambda x: x[:, 1:2])

first = True
for layer in shared_layers:
    if first:
        x1_nn = layer_extract_speed(x1_nn_input)
        x2_nn = layer_extract_speed(x2_nn_input)
        x1_nn = layer(x1_nn)
        x2_nn = layer(x2_nn)
        first = False    
    else:
        x1_nn = layer(x1_nn)
        x2_nn = layer(x2_nn)
        
x1_nn = x1_nn*layer_extract_vib(x1_nn_input)
x2_nn = x2_nn*layer_extract_vib(x2_nn_input)        

y_nn = keras.layers.Lambda(lambda x12: keras.backend.tanh(x12[0] - x12[1]), name='ranker')((x1_nn, x2_nn))

model = keras.models.Model(inputs=[x1_nn_input, x2_nn_input], outputs=[y_nn])
model.summary()
# Out:
# Model: "model_28"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_43 (InputLayer)       [(None, 2)]                  0         []
#
#  input_44 (InputLayer)       [(None, 2)]                  0         []
#
#  lambda_32 (Lambda)          (None, 1)                    0         ['input_43[0][0]',
#                                                                      'input_44[0][0]']
#
#  dense_63 (Dense)            (None, 8)                    16        ['lambda_32[0][0]',
#                                                                      'lambda_32[1][0]']
#
#  dropout_42 (Dropout)        (None, 8)                    0         ['dense_63[0][0]',
#                                                                      'dense_63[1][0]']
#
#  batch_normalization_42 (Ba  (None, 8)                    32        ['dropout_42[0][0]',
#  tchNormalization)                                                   'dropout_42[1][0]']
#
#  dense_64 (Dense)            (None, 4)                    36        ['batch_normalization_42[0][0]
#                                                                     ',
#                                                                      'batch_normalization_42[1][0]
#                                                                     ']
#
#  dropout_43 (Dropout)        (None, 4)                    0         ['dense_64[0][0]',
#                                                                      'dense_64[1][0]']
#
#  batch_normalization_43 (Ba  (None, 4)                    16        ['dropout_43[0][0]',
#  tchNormalization)                                                   'dropout_43[1][0]']
#
#  dense_65 (Dense)            (None, 1)                    5         ['batch_normalization_43[0][0]
#                                                                     ',
#                                                                      'batch_normalization_43[1][0]
#                                                                     ']
#
#  lambda_33 (Lambda)          (None, 1)                    0         ['input_43[0][0]',
#                                                                      'input_44[0][0]']
#
#  tf.math.multiply_16 (TFOpL  (None, 1)                    0         ['dense_65[0][0]',
#  ambda)                                                              'lambda_33[0][0]']
#
#  tf.math.multiply_17 (TFOpL  (None, 1)                    0         ['dense_65[1][0]',
#  ambda)                                                              'lambda_33[1][0]']
#
#  ranker (Lambda)             (None, 1)                    0         ['tf.math.multiply_16[0][0]',
#                                                                      'tf.math.multiply_17[0][0]']
#
# ==================================================================================================
# Total params: 105 (420.00 Byte)
# Trainable params: 81 (324.00 Byte)
# Non-trainable params: 24 (96.00 Byte)
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, to_file='model.pdf',
                        show_shapes=True,
                        show_dtype=False,
                        show_layer_names=True,
                        expand_nested=True,
                        dpi=96,
                        layer_range=None,
                        show_layer_activations=True,
                        show_trainable=True)

# %%
model_x1 = keras.models.Model(inputs=[x1_nn_input], outputs=[x1_nn])
model_x1.build(input_shape=x1_nn_input.shape)
# model_x1.summary()

# %% [markdown]
# ## Model training

# %%
learning_rate = .5
batch_size = X_train.shape[0]
epochs = 500
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.9,
                                              patience=20, verbose=1,min_lr=0)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=500,)

model.compile(optimizer=keras.optimizers.SGD(learning_rate=learning_rate), loss='mse')
history = model.fit(x=[X_train[:, :2], X_train[:, 2:]], y=[y_train], batch_size=batch_size, epochs=epochs, 
                    validation_split=0.1,
                    callbacks=[reduce_lr, early_stopping])
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/500
# 1/1 [==============================] - 3s 3s/step - loss: 1.5114 - val_loss: 0.7073 - lr: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 49ms/step - loss: 1.7984 - val_loss: 0.6859 - lr: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 51ms/step - loss: 1.0167 - val_loss: 0.6692 - lr: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5142 - val_loss: 0.6126 - lr: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4642 - val_loss: 0.7737 - lr: 0.5000
# Epoch 6/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5865 - val_loss: 0.7210 - lr: 0.5000
# Epoch 7/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5512 - val_loss: 0.6674 - lr: 0.5000
# Epoch 8/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5236 - val_loss: 0.6260 - lr: 0.5000
# Epoch 9/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5108 - val_loss: 0.6077 - lr: 0.5000
# Epoch 10/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5051 - val_loss: 0.5956 - lr: 0.5000
# Epoch 11/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4983 - val_loss: 0.5797 - lr: 0.5000
# Epoch 12/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4864 - val_loss: 0.5597 - lr: 0.5000
# Epoch 13/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4474 - val_loss: 0.5456 - lr: 0.5000
# Epoch 14/500
# 1/1 [==============================] - 0s 52ms/step - loss: 1.4724 - val_loss: 0.6659 - lr: 0.5000
# Epoch 15/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5332 - val_loss: 0.6180 - lr: 0.5000
# Epoch 16/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5082 - val_loss: 0.5769 - lr: 0.5000
# Epoch 17/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4912 - val_loss: 0.5493 - lr: 0.5000
# Epoch 18/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4814 - val_loss: 0.5339 - lr: 0.5000
# Epoch 19/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4664 - val_loss: 0.5183 - lr: 0.5000
# Epoch 20/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.4294 - val_loss: 0.6564 - lr: 0.5000
# Epoch 21/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5398 - val_loss: 0.6076 - lr: 0.5000
# Epoch 22/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5132 - val_loss: 0.5616 - lr: 0.5000
# Epoch 23/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4913 - val_loss: 0.5257 - lr: 0.5000
# Epoch 24/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4777 - val_loss: 0.5043 - lr: 0.5000
# Epoch 25/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4699 - val_loss: 0.4939 - lr: 0.5000
# Epoch 26/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4592 - val_loss: 0.4977 - lr: 0.5000
# Epoch 27/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4226 - val_loss: 0.6609 - lr: 0.5000
# Epoch 28/500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.1371 - val_loss: 0.7850 - lr: 0.5000
# Epoch 29/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5629 - val_loss: 0.7488 - lr: 0.5000
# Epoch 30/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5303 - val_loss: 0.7076 - lr: 0.5000
# Epoch 31/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4994 - val_loss: 0.6649 - lr: 0.5000
# Epoch 32/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4769 - val_loss: 0.6303 - lr: 0.5000
# Epoch 33/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4584 - val_loss: 0.6002 - lr: 0.5000
# Epoch 34/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4111 - val_loss: 0.6726 - lr: 0.5000
# Epoch 35/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4632 - val_loss: 0.6011 - lr: 0.5000
# Epoch 36/500
# 1/1 [==============================] - 0s 53ms/step - loss: 1.3274 - val_loss: 0.7174 - lr: 0.5000
# Epoch 37/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5710 - val_loss: 0.6844 - lr: 0.5000
# Epoch 38/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5469 - val_loss: 0.6473 - lr: 0.5000
# Epoch 39/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5220 - val_loss: 0.6068 - lr: 0.5000
# Epoch 40/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4982 - val_loss: 0.5660 - lr: 0.5000
# Epoch 41/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4790 - val_loss: 0.5311 - lr: 0.5000
# Epoch 42/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4673 - val_loss: 0.5072 - lr: 0.5000
# Epoch 43/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4613 - val_loss: 0.4916 - lr: 0.5000
# Epoch 44/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4575 - val_loss: 0.4796 - lr: 0.5000
# Epoch 45/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4542 - val_loss: 0.4693 - lr: 0.5000
# Epoch 46/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4509 - val_loss: 0.4599 - lr: 0.5000
# Epoch 47/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4469 - val_loss: 0.4513 - lr: 0.5000
# Epoch 48/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4412 - val_loss: 0.4436 - lr: 0.5000
# Epoch 49/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4301 - val_loss: 0.4391 - lr: 0.5000
# Epoch 50/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3926 - val_loss: 0.4321 - lr: 0.5000
# Epoch 51/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.7470 - val_loss: 0.7086 - lr: 0.5000
# Epoch 52/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6305 - val_loss: 0.6571 - lr: 0.5000
# Epoch 53/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5964 - val_loss: 0.5890 - lr: 0.5000
# Epoch 54/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5555 - val_loss: 0.5040 - lr: 0.5000
# Epoch 55/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5048 - val_loss: 0.4735 - lr: 0.5000
# Epoch 56/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4357 - val_loss: 2.0288 - lr: 0.5000
# Epoch 57/500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.5010 - val_loss: 0.6464 - lr: 0.5000
# Epoch 58/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5651 - val_loss: 0.5644 - lr: 0.5000
# Epoch 59/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4951 - val_loss: 0.4638 - lr: 0.5000
# Epoch 60/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4273 - val_loss: 0.7268 - lr: 0.5000
# Epoch 61/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5999 - val_loss: 0.6924 - lr: 0.5000
# Epoch 62/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5708 - val_loss: 0.6498 - lr: 0.5000
# Epoch 63/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5365 - val_loss: 0.5946 - lr: 0.5000
# Epoch 64/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4930 - val_loss: 0.5221 - lr: 0.5000
# Epoch 65/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3832 - val_loss: 0.6736 - lr: 0.5000
# Epoch 66/500
# 1/1 [==============================] - 0s 49ms/step - loss: 1.3211 - val_loss: 0.6285 - lr: 0.5000
# Epoch 67/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4582 - val_loss: 0.6346 - lr: 0.5000
# Epoch 68/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4170 - val_loss: 0.5607 - lr: 0.5000
# Epoch 69/500
# 1/1 [==============================] - 0s 50ms/step - loss: 1.4134 - val_loss: 0.7037 - lr: 0.5000
# Epoch 70/500
# 1/1 [==============================] - ETA: 0s - loss: 0.7455
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.45.
# 1/1 [==============================] - 0s 61ms/step - loss: 0.7455 - val_loss: 0.6988 - lr: 0.5000
# Epoch 71/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6455 - val_loss: 0.6633 - lr: 0.4500
# Epoch 72/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6236 - val_loss: 0.6241 - lr: 0.4500
# Epoch 73/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.6001 - val_loss: 0.5826 - lr: 0.4500
# Epoch 74/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.5748 - val_loss: 0.5426 - lr: 0.4500
# Epoch 75/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5482 - val_loss: 0.5151 - lr: 0.4500
# Epoch 76/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.5218 - val_loss: 0.5306 - lr: 0.4500
# Epoch 77/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4986 - val_loss: 0.6912 - lr: 0.4500
# Epoch 78/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4742 - val_loss: 1.2195 - lr: 0.4500
# Epoch 79/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5704 - val_loss: 0.8546 - lr: 0.4500
# Epoch 80/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.7279 - val_loss: 0.8361 - lr: 0.4500
# Epoch 81/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.7106 - val_loss: 0.8167 - lr: 0.4500
# Epoch 82/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.6930 - val_loss: 0.7964 - lr: 0.4500
# Epoch 83/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.6749 - val_loss: 0.7748 - lr: 0.4500
# Epoch 84/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6562 - val_loss: 0.7514 - lr: 0.4500
# Epoch 85/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.6365 - val_loss: 0.7260 - lr: 0.4500
# Epoch 86/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6157 - val_loss: 0.6980 - lr: 0.4500
# Epoch 87/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5937 - val_loss: 0.6671 - lr: 0.4500
# Epoch 88/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5702 - val_loss: 0.6334 - lr: 0.4500
# Epoch 89/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5455 - val_loss: 0.5974 - lr: 0.4500
# Epoch 90/500
# 1/1 [==============================] - ETA: 0s - loss: 0.5205
# Epoch 90: ReduceLROnPlateau reducing learning rate to 0.40499998927116393.
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5205 - val_loss: 0.5616 - lr: 0.4500
# Epoch 91/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4969 - val_loss: 0.5327 - lr: 0.4050
# Epoch 92/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4780 - val_loss: 0.5092 - lr: 0.4050
# Epoch 93/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4549 - val_loss: 0.4898 - lr: 0.4050
# Epoch 94/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4874 - val_loss: 0.7083 - lr: 0.4050
# Epoch 95/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.6272 - val_loss: 0.6861 - lr: 0.4050
# Epoch 96/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.6109 - val_loss: 0.6623 - lr: 0.4050
# Epoch 97/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5940 - val_loss: 0.6369 - lr: 0.4050
# Epoch 98/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5764 - val_loss: 0.6099 - lr: 0.4050
# Epoch 99/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5582 - val_loss: 0.5818 - lr: 0.4050
# Epoch 100/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.5396 - val_loss: 0.5533 - lr: 0.4050
# Epoch 101/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5211 - val_loss: 0.5260 - lr: 0.4050
# Epoch 102/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5036 - val_loss: 0.5019 - lr: 0.4050
# Epoch 103/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4885 - val_loss: 0.4832 - lr: 0.4050
# Epoch 104/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4770 - val_loss: 0.4711 - lr: 0.4050
# Epoch 105/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4698 - val_loss: 0.4644 - lr: 0.4050
# Epoch 106/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4652 - val_loss: 0.4606 - lr: 0.4050
# Epoch 107/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.4602 - val_loss: 0.4575 - lr: 0.4050
# Epoch 108/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4501 - val_loss: 0.4544 - lr: 0.4050
# Epoch 109/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4155 - val_loss: 0.4435 - lr: 0.4050
# Epoch 110/500
# 1/1 [==============================] - ETA: 0s - loss: 0.5415
# Epoch 110: ReduceLROnPlateau reducing learning rate to 0.3645000010728836.
# 1/1 [==============================] - 0s 54ms/step - loss: 0.5415 - val_loss: 0.6657 - lr: 0.4050
# Epoch 111/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6065 - val_loss: 0.6442 - lr: 0.3645
# Epoch 112/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5916 - val_loss: 0.6208 - lr: 0.3645
# Epoch 113/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5760 - val_loss: 0.5956 - lr: 0.3645
# Epoch 114/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5597 - val_loss: 0.5685 - lr: 0.3645
# Epoch 115/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5425 - val_loss: 0.5401 - lr: 0.3645
# Epoch 116/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5248 - val_loss: 0.5112 - lr: 0.3645
# Epoch 117/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.5069 - val_loss: 0.4839 - lr: 0.3645
# Epoch 118/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4897 - val_loss: 0.4611 - lr: 0.3645
# Epoch 119/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4748 - val_loss: 0.4463 - lr: 0.3645
# Epoch 120/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4635 - val_loss: 0.4412 - lr: 0.3645
# Epoch 121/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4561 - val_loss: 0.4437 - lr: 0.3645
# Epoch 122/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4502 - val_loss: 0.4524 - lr: 0.3645
# Epoch 123/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4414 - val_loss: 0.4805 - lr: 0.3645
# Epoch 124/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4170 - val_loss: 0.6790 - lr: 0.3645
# Epoch 125/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4408 - val_loss: 0.6096 - lr: 0.3645
# Epoch 126/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.5601 - val_loss: 0.5868 - lr: 0.3645
# Epoch 127/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5450 - val_loss: 0.5625 - lr: 0.3645
# Epoch 128/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5293 - val_loss: 0.5370 - lr: 0.3645
# Epoch 129/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.5130 - val_loss: 0.5108 - lr: 0.3645
# Epoch 130/500
# 1/1 [==============================] - ETA: 0s - loss: 0.4965
# Epoch 130: ReduceLROnPlateau reducing learning rate to 0.32804998755455017.
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4965 - val_loss: 0.4848 - lr: 0.3645
# Epoch 131/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4801 - val_loss: 0.4630 - lr: 0.3280
# Epoch 132/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4658 - val_loss: 0.4440 - lr: 0.3280
# Epoch 133/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4523 - val_loss: 0.4295 - lr: 0.3280
# Epoch 134/500
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4393 - val_loss: 0.4216 - lr: 0.3280
# Epoch 135/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4254 - val_loss: 0.4253 - lr: 0.3280
# Epoch 136/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4074 - val_loss: 0.4670 - lr: 0.3280
# Epoch 137/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3838 - val_loss: 0.4790 - lr: 0.3280
# Epoch 138/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3684 - val_loss: 0.4286 - lr: 0.3280
# Epoch 139/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3656 - val_loss: 0.6863 - lr: 0.3280
# Epoch 140/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4697 - val_loss: 0.5819 - lr: 0.3280
# Epoch 141/500
# 1/1 [==============================] - 0s 207ms/step - loss: 0.5424 - val_loss: 0.5616 - lr: 0.3280
# Epoch 142/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.5289 - val_loss: 0.5403 - lr: 0.3280
# Epoch 143/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.5149 - val_loss: 0.5182 - lr: 0.3280
# Epoch 144/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5007 - val_loss: 0.4959 - lr: 0.3280
# Epoch 145/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4864 - val_loss: 0.4740 - lr: 0.3280
# Epoch 146/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.4723 - val_loss: 0.4535 - lr: 0.3280
# Epoch 147/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4589 - val_loss: 0.4356 - lr: 0.3280
# Epoch 148/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4469 - val_loss: 0.4216 - lr: 0.3280
# Epoch 149/500
# 1/1 [==============================] - 0s 219ms/step - loss: 0.4369 - val_loss: 0.4122 - lr: 0.3280
# Epoch 150/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.4289 - val_loss: 0.4075 - lr: 0.3280
# Epoch 151/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4222 - val_loss: 0.4067 - lr: 0.3280
# Epoch 152/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4151 - val_loss: 0.4099 - lr: 0.3280
# Epoch 153/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4057 - val_loss: 0.4207 - lr: 0.3280
# Epoch 154/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3924 - val_loss: 0.4504 - lr: 0.3280
# Epoch 155/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3749 - val_loss: 0.4699 - lr: 0.3280
# Epoch 156/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3588 - val_loss: 0.4296 - lr: 0.3280
# Epoch 157/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3496 - val_loss: 0.5501 - lr: 0.3280
# Epoch 158/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3738 - val_loss: 0.4432 - lr: 0.3280
# Epoch 159/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4522 - val_loss: 0.4202 - lr: 0.3280
# Epoch 160/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.4327 - val_loss: 0.4005 - lr: 0.3280
# Epoch 161/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4115 - val_loss: 0.3884 - lr: 0.3280
# Epoch 162/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3832 - val_loss: 0.4283 - lr: 0.3280
# Epoch 163/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3428 - val_loss: 0.4157 - lr: 0.3280
# Epoch 164/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3380 - val_loss: 0.4399 - lr: 0.3280
# Epoch 165/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3390 - val_loss: 0.3843 - lr: 0.3280
# Epoch 166/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3817 - val_loss: 0.4267 - lr: 0.3280
# Epoch 167/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3379 - val_loss: 0.3845 - lr: 0.3280
# Epoch 168/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3857 - val_loss: 0.4015 - lr: 0.3280
# Epoch 169/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3318 - val_loss: 0.3912 - lr: 0.3280
# Epoch 170/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3314 - val_loss: 0.4552 - lr: 0.3280
# Epoch 171/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3604 - val_loss: 0.4340 - lr: 0.3280
# Epoch 172/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.4475 - val_loss: 0.4107 - lr: 0.3280
# Epoch 173/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4258 - val_loss: 0.3911 - lr: 0.3280
# Epoch 174/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4027 - val_loss: 0.3791 - lr: 0.3280
# Epoch 175/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3700 - val_loss: 0.4418 - lr: 0.3280
# Epoch 176/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3415 - val_loss: 0.3842 - lr: 0.3280
# Epoch 177/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3944 - val_loss: 0.3699 - lr: 0.3280
# Epoch 178/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3522 - val_loss: 0.5218 - lr: 0.3280
# Epoch 179/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4097 - val_loss: 0.4920 - lr: 0.3280
# Epoch 180/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4834 - val_loss: 0.4675 - lr: 0.3280
# Epoch 181/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4666 - val_loss: 0.4436 - lr: 0.3280
# Epoch 182/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4498 - val_loss: 0.4212 - lr: 0.3280
# Epoch 183/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4331 - val_loss: 0.4019 - lr: 0.3280
# Epoch 184/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4169 - val_loss: 0.3873 - lr: 0.3280
# Epoch 185/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4009 - val_loss: 0.3811 - lr: 0.3280
# Epoch 186/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3837 - val_loss: 0.3947 - lr: 0.3280
# Epoch 187/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3618 - val_loss: 0.4783 - lr: 0.3280
# Epoch 188/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3450 - val_loss: 0.3740 - lr: 0.3280
# Epoch 189/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3510 - val_loss: 0.5920 - lr: 0.3280
# Epoch 190/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3649 - val_loss: 0.4251 - lr: 0.3280
# Epoch 191/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4362 - val_loss: 0.4007 - lr: 0.3280
# Epoch 192/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4171 - val_loss: 0.3792 - lr: 0.3280
# Epoch 193/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3963 - val_loss: 0.3640 - lr: 0.3280
# Epoch 194/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3691 - val_loss: 0.3934 - lr: 0.3280
# Epoch 195/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3282 - val_loss: 0.4392 - lr: 0.3280
# Epoch 196/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3313 - val_loss: 0.3649 - lr: 0.3280
# Epoch 197/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3823 - val_loss: 0.3485 - lr: 0.3280
# Epoch 198/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3360 - val_loss: 0.5623 - lr: 0.3280
# Epoch 199/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4053 - val_loss: 0.4814 - lr: 0.3280
# Epoch 200/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4705 - val_loss: 0.4554 - lr: 0.3280
# Epoch 201/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4530 - val_loss: 0.4299 - lr: 0.3280
# Epoch 202/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4353 - val_loss: 0.4058 - lr: 0.3280
# Epoch 203/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4175 - val_loss: 0.3842 - lr: 0.3280
# Epoch 204/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3991 - val_loss: 0.3668 - lr: 0.3280
# Epoch 205/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3785 - val_loss: 0.3600 - lr: 0.3280
# Epoch 206/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3510 - val_loss: 0.4183 - lr: 0.3280
# Epoch 207/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3343 - val_loss: 0.3517 - lr: 0.3280
# Epoch 208/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3606 - val_loss: 0.3697 - lr: 0.3280
# Epoch 209/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3193 - val_loss: 0.3462 - lr: 0.3280
# Epoch 210/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3206 - val_loss: 0.4812 - lr: 0.3280
# Epoch 211/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3724 - val_loss: 0.4468 - lr: 0.3280
# Epoch 212/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4443 - val_loss: 0.4198 - lr: 0.3280
# Epoch 213/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4253 - val_loss: 0.3939 - lr: 0.3280
# Epoch 214/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4056 - val_loss: 0.3695 - lr: 0.3280
# Epoch 215/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3834 - val_loss: 0.3476 - lr: 0.3280
# Epoch 216/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3529 - val_loss: 0.3566 - lr: 0.3280
# Epoch 217/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3216 - val_loss: 0.3378 - lr: 0.3280
# Epoch 218/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3377 - val_loss: 0.3940 - lr: 0.3280
# Epoch 219/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3659 - val_loss: 0.4412 - lr: 0.3280
# Epoch 220/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4380 - val_loss: 0.4140 - lr: 0.3280
# Epoch 221/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4188 - val_loss: 0.3881 - lr: 0.3280
# Epoch 222/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3988 - val_loss: 0.3641 - lr: 0.3280
# Epoch 223/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3762 - val_loss: 0.3443 - lr: 0.3280
# Epoch 224/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3447 - val_loss: 0.3707 - lr: 0.3280
# Epoch 225/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3252 - val_loss: 0.3510 - lr: 0.3280
# Epoch 226/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3617 - val_loss: 0.3294 - lr: 0.3280
# Epoch 227/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3141 - val_loss: 0.3653 - lr: 0.3280
# Epoch 228/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3347 - val_loss: 0.3951 - lr: 0.3280
# Epoch 229/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4026 - val_loss: 0.3667 - lr: 0.3280
# Epoch 230/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3784 - val_loss: 0.3379 - lr: 0.3280
# Epoch 231/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3422 - val_loss: 0.3523 - lr: 0.3280
# Epoch 232/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3257 - val_loss: 0.3744 - lr: 0.3280
# Epoch 233/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3842 - val_loss: 0.3422 - lr: 0.3280
# Epoch 234/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3510 - val_loss: 0.3219 - lr: 0.3280
# Epoch 235/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3091 - val_loss: 0.3220 - lr: 0.3280
# Epoch 236/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3203 - val_loss: 0.3793 - lr: 0.3280
# Epoch 237/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3871 - val_loss: 0.4656 - lr: 0.3280
# Epoch 238/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4494 - val_loss: 0.4377 - lr: 0.3280
# Epoch 239/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4306 - val_loss: 0.4103 - lr: 0.3280
# Epoch 240/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.4118 - val_loss: 0.3839 - lr: 0.3280
# Epoch 241/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3924 - val_loss: 0.3588 - lr: 0.3280
# Epoch 242/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3707 - val_loss: 0.3364 - lr: 0.3280
# Epoch 243/500
# 1/1 [==============================] - 0s 129ms/step - loss: 0.3425 - val_loss: 0.3385 - lr: 0.3280
# Epoch 244/500
# 1/1 [==============================] - 0s 197ms/step - loss: 0.3172 - val_loss: 0.3213 - lr: 0.3280
# Epoch 245/500
# 1/1 [==============================] - 0s 183ms/step - loss: 0.3237 - val_loss: 0.3668 - lr: 0.3280
# Epoch 246/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.3593 - val_loss: 0.4396 - lr: 0.3280
# Epoch 247/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.4285 - val_loss: 0.4106 - lr: 0.3280
# Epoch 248/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4089 - val_loss: 0.3815 - lr: 0.3280
# Epoch 249/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3880 - val_loss: 0.3514 - lr: 0.3280
# Epoch 250/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3631 - val_loss: 0.3203 - lr: 0.3280
# Epoch 251/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.3266 - val_loss: 0.3375 - lr: 0.3280
# Epoch 252/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.3337 - val_loss: 0.3984 - lr: 0.3280
# Epoch 253/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.3967 - val_loss: 0.3661 - lr: 0.3280
# Epoch 254/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.3728 - val_loss: 0.3290 - lr: 0.3280
# Epoch 255/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3392 - val_loss: 0.3068 - lr: 0.3280
# Epoch 256/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3092 - val_loss: 0.3290 - lr: 0.3280
# Epoch 257/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3358 - val_loss: 0.3081 - lr: 0.3280
# Epoch 258/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3178 - val_loss: 0.3732 - lr: 0.3280
# Epoch 259/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3761 - val_loss: 0.3353 - lr: 0.3280
# Epoch 260/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3423 - val_loss: 0.3012 - lr: 0.3280
# Epoch 261/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3034 - val_loss: 0.3150 - lr: 0.3280
# Epoch 262/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3148 - val_loss: 0.3408 - lr: 0.3280
# Epoch 263/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3696 - val_loss: 0.4509 - lr: 0.3280
# Epoch 264/500
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4533 - val_loss: 0.4133 - lr: 0.3280
# Epoch 265/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4138 - val_loss: 0.3821 - lr: 0.3280
# Epoch 266/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3945 - val_loss: 0.3474 - lr: 0.3280
# Epoch 267/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3734 - val_loss: 0.3137 - lr: 0.3280
# Epoch 268/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3480 - val_loss: 0.3188 - lr: 0.3280
# Epoch 269/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3161 - val_loss: 0.3694 - lr: 0.3280
# Epoch 270/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3148 - val_loss: 0.3415 - lr: 0.3280
# Epoch 271/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3445 - val_loss: 0.3378 - lr: 0.3280
# Epoch 272/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3119 - val_loss: 0.3158 - lr: 0.3280
# Epoch 273/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3277 - val_loss: 0.4821 - lr: 0.3280
# Epoch 274/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3986 - val_loss: 0.4432 - lr: 0.3280
# Epoch 275/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3701 - val_loss: 0.3421 - lr: 0.3280
# Epoch 276/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3567 - val_loss: 0.3098 - lr: 0.3280
# Epoch 277/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3176 - val_loss: 0.3055 - lr: 0.3280
# Epoch 278/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3013 - val_loss: 0.3587 - lr: 0.3280
# Epoch 279/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3931 - val_loss: 0.3919 - lr: 0.3280
# Epoch 280/500
# 1/1 [==============================] - ETA: 0s - loss: 0.3611
# Epoch 280: ReduceLROnPlateau reducing learning rate to 0.29524498879909516.
# 1/1 [==============================] - 0s 122ms/step - loss: 0.3611 - val_loss: 0.3698 - lr: 0.3280
# Epoch 281/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.3206 - val_loss: 0.4210 - lr: 0.2952
# Epoch 282/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3229 - val_loss: 0.4261 - lr: 0.2952
# Epoch 283/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3764 - val_loss: 0.3919 - lr: 0.2952
# Epoch 284/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3466 - val_loss: 0.3570 - lr: 0.2952
# Epoch 285/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2990 - val_loss: 0.3378 - lr: 0.2952
# Epoch 286/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2971 - val_loss: 0.3703 - lr: 0.2952
# Epoch 287/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3872 - val_loss: 0.3507 - lr: 0.2952
# Epoch 288/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3727 - val_loss: 0.3705 - lr: 0.2952
# Epoch 289/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3188 - val_loss: 0.7448 - lr: 0.2952
# Epoch 290/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3332 - val_loss: 0.3413 - lr: 0.2952
# Epoch 291/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3898 - val_loss: 0.3123 - lr: 0.2952
# Epoch 292/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3664 - val_loss: 0.3080 - lr: 0.2952
# Epoch 293/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3325 - val_loss: 0.5275 - lr: 0.2952
# Epoch 294/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3078 - val_loss: 0.3027 - lr: 0.2952
# Epoch 295/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3342 - val_loss: 0.5359 - lr: 0.2952
# Epoch 296/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3062 - val_loss: 0.3007 - lr: 0.2952
# Epoch 297/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3416 - val_loss: 0.4461 - lr: 0.2952
# Epoch 298/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2983 - val_loss: 0.3591 - lr: 0.2952
# Epoch 299/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3013 - val_loss: 0.6495 - lr: 0.2952
# Epoch 300/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3316 - val_loss: 0.3630 - lr: 0.2952
# Epoch 301/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3948 - val_loss: 0.3233 - lr: 0.2952
# Epoch 302/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3668 - val_loss: 0.3026 - lr: 0.2952
# Epoch 303/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3322 - val_loss: 0.4446 - lr: 0.2952
# Epoch 304/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2985 - val_loss: 0.3243 - lr: 0.2952
# Epoch 305/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3080 - val_loss: 1.3819 - lr: 0.2952
# Epoch 306/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3453 - val_loss: 0.4341 - lr: 0.2952
# Epoch 307/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4517 - val_loss: 0.4075 - lr: 0.2952
# Epoch 308/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4324 - val_loss: 0.3800 - lr: 0.2952
# Epoch 309/500
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4107 - val_loss: 0.3540 - lr: 0.2952
# Epoch 310/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3826 - val_loss: 0.3731 - lr: 0.2952
# Epoch 311/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3464 - val_loss: 0.4197 - lr: 0.2952
# Epoch 312/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3444 - val_loss: 0.3399 - lr: 0.2952
# Epoch 313/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3675 - val_loss: 0.4505 - lr: 0.2952
# Epoch 314/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3540 - val_loss: 0.3768 - lr: 0.2952
# Epoch 315/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4049 - val_loss: 0.3430 - lr: 0.2952
# Epoch 316/500
# 1/1 [==============================] - ETA: 0s - loss: 0.3667
# Epoch 316: ReduceLROnPlateau reducing learning rate to 0.2657204926013947.
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3667 - val_loss: 0.4140 - lr: 0.2952
# Epoch 317/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3477 - val_loss: 0.3578 - lr: 0.2657
# Epoch 318/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3843 - val_loss: 0.3391 - lr: 0.2657
# Epoch 319/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3392 - val_loss: 0.4179 - lr: 0.2657
# Epoch 320/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3546 - val_loss: 0.3806 - lr: 0.2657
# Epoch 321/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4011 - val_loss: 0.3479 - lr: 0.2657
# Epoch 322/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3664 - val_loss: 0.3613 - lr: 0.2657
# Epoch 323/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3345 - val_loss: 0.3373 - lr: 0.2657
# Epoch 324/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3458 - val_loss: 0.4102 - lr: 0.2657
# Epoch 325/500
# 1/1 [==============================] - 0s 135ms/step - loss: 0.3610 - val_loss: 0.3986 - lr: 0.2657
# Epoch 326/500
# 1/1 [==============================] - 0s 145ms/step - loss: 0.4112 - val_loss: 0.3679 - lr: 0.2657
# Epoch 327/500
# 1/1 [==============================] - 0s 257ms/step - loss: 0.3831 - val_loss: 0.3393 - lr: 0.2657
# Epoch 328/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3395 - val_loss: 0.4052 - lr: 0.2657
# Epoch 329/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.3432 - val_loss: 0.6753 - lr: 0.2657
# Epoch 330/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4240 - val_loss: 0.4174 - lr: 0.2657
# Epoch 331/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.3793 - val_loss: 0.3959 - lr: 0.2657
# Epoch 332/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3433 - val_loss: 0.3844 - lr: 0.2657
# Epoch 333/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.3452 - val_loss: 0.4258 - lr: 0.2657
# Epoch 334/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.3819 - val_loss: 0.3791 - lr: 0.2657
# Epoch 335/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.3284 - val_loss: 0.4522 - lr: 0.2657
# Epoch 336/500
# 1/1 [==============================] - ETA: 0s - loss: 0.3602
# Epoch 336: ReduceLROnPlateau reducing learning rate to 0.23914843797683716.
# 1/1 [==============================] - 0s 67ms/step - loss: 0.3602 - val_loss: 0.4450 - lr: 0.2657
# Epoch 337/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3907 - val_loss: 0.7075 - lr: 0.2391
# Epoch 338/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5377 - val_loss: 0.6776 - lr: 0.2391
# Epoch 339/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.5016 - val_loss: 0.6523 - lr: 0.2391
# Epoch 340/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4734 - val_loss: 0.6787 - lr: 0.2391
# Epoch 341/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4838 - val_loss: 0.6590 - lr: 0.2391
# Epoch 342/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4866 - val_loss: 0.7011 - lr: 0.2391
# Epoch 343/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5250 - val_loss: 0.6710 - lr: 0.2391
# Epoch 344/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4842 - val_loss: 0.6489 - lr: 0.2391
# Epoch 345/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4745 - val_loss: 0.6873 - lr: 0.2391
# Epoch 346/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5071 - val_loss: 0.6577 - lr: 0.2391
# Epoch 347/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4608 - val_loss: 0.6513 - lr: 0.2391
# Epoch 348/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4692 - val_loss: 0.6844 - lr: 0.2391
# Epoch 349/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5024 - val_loss: 0.6542 - lr: 0.2391
# Epoch 350/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4554 - val_loss: 0.6473 - lr: 0.2391
# Epoch 351/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4636 - val_loss: 0.6783 - lr: 0.2391
# Epoch 352/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4963 - val_loss: 0.6475 - lr: 0.2391
# Epoch 353/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4492 - val_loss: 0.6419 - lr: 0.2391
# Epoch 354/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4551 - val_loss: 0.6681 - lr: 0.2391
# Epoch 355/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4828 - val_loss: 0.6372 - lr: 0.2391
# Epoch 356/500
# 1/1 [==============================] - ETA: 0s - loss: 0.4426
# Epoch 356: ReduceLROnPlateau reducing learning rate to 0.21523359417915344.
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4426 - val_loss: 0.6463 - lr: 0.2391
# Epoch 357/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4433 - val_loss: 0.6369 - lr: 0.2152
# Epoch 358/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4478 - val_loss: 0.6569 - lr: 0.2152
# Epoch 359/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4675 - val_loss: 0.6285 - lr: 0.2152
# Epoch 360/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.4404 - val_loss: 0.6440 - lr: 0.2152
# Epoch 361/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4508 - val_loss: 0.6200 - lr: 0.2152
# Epoch 362/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4499 - val_loss: 0.6508 - lr: 0.2152
# Epoch 363/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4775 - val_loss: 0.6177 - lr: 0.2152
# Epoch 364/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4332 - val_loss: 0.6087 - lr: 0.2152
# Epoch 365/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4361 - val_loss: 0.6306 - lr: 0.2152
# Epoch 366/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4509 - val_loss: 0.5995 - lr: 0.2152
# Epoch 367/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4382 - val_loss: 0.6301 - lr: 0.2152
# Epoch 368/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4606 - val_loss: 0.5943 - lr: 0.2152
# Epoch 369/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4259 - val_loss: 0.6057 - lr: 0.2152
# Epoch 370/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4277 - val_loss: 0.5883 - lr: 0.2152
# Epoch 371/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4337 - val_loss: 0.6223 - lr: 0.2152
# Epoch 372/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4569 - val_loss: 0.5825 - lr: 0.2152
# Epoch 373/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4206 - val_loss: 0.5934 - lr: 0.2152
# Epoch 374/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4215 - val_loss: 0.5775 - lr: 0.2152
# Epoch 375/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4261 - val_loss: 0.6113 - lr: 0.2152
# Epoch 376/500
# 1/1 [==============================] - ETA: 0s - loss: 0.4465
# Epoch 376: ReduceLROnPlateau reducing learning rate to 0.1937102347612381.
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4465 - val_loss: 0.5669 - lr: 0.2152
# Epoch 377/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.4190 - val_loss: 0.5909 - lr: 0.1937
# Epoch 378/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4267 - val_loss: 0.5570 - lr: 0.1937
# Epoch 379/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4222 - val_loss: 0.5856 - lr: 0.1937
# Epoch 380/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4401 - val_loss: 0.5023 - lr: 0.1937
# Epoch 381/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4031 - val_loss: 0.6238 - lr: 0.1937
# Epoch 382/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3800 - val_loss: 0.5135 - lr: 0.1937
# Epoch 383/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4375 - val_loss: 0.6421 - lr: 0.1937
# Epoch 384/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4501 - val_loss: 0.6199 - lr: 0.1937
# Epoch 385/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4076 - val_loss: 0.6280 - lr: 0.1937
# Epoch 386/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3827 - val_loss: 0.6049 - lr: 0.1937
# Epoch 387/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4794 - val_loss: 0.4458 - lr: 0.1937
# Epoch 388/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4127 - val_loss: 0.4794 - lr: 0.1937
# Epoch 389/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4110 - val_loss: 0.4036 - lr: 0.1937
# Epoch 390/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4136 - val_loss: 0.4538 - lr: 0.1937
# Epoch 391/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4129 - val_loss: 0.4087 - lr: 0.1937
# Epoch 392/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4252 - val_loss: 0.4123 - lr: 0.1937
# Epoch 393/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4065 - val_loss: 0.4059 - lr: 0.1937
# Epoch 394/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4130 - val_loss: 0.4044 - lr: 0.1937
# Epoch 395/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4103 - val_loss: 0.4304 - lr: 0.1937
# Epoch 396/500
# 1/1 [==============================] - ETA: 0s - loss: 0.4255
# Epoch 396: ReduceLROnPlateau reducing learning rate to 0.1743392139673233.
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4255 - val_loss: 0.3924 - lr: 0.1937
# Epoch 397/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4010 - val_loss: 0.4102 - lr: 0.1743
# Epoch 398/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4032 - val_loss: 0.3904 - lr: 0.1743
# Epoch 399/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4026 - val_loss: 0.4260 - lr: 0.1743
# Epoch 400/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4088 - val_loss: 0.3903 - lr: 0.1743
# Epoch 401/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4014 - val_loss: 0.4315 - lr: 0.1743
# Epoch 402/500
# 1/1 [==============================] - 0s 170ms/step - loss: 0.4080 - val_loss: 0.3917 - lr: 0.1743
# Epoch 403/500
# 1/1 [==============================] - 0s 257ms/step - loss: 0.3997 - val_loss: 0.4350 - lr: 0.1743
# Epoch 404/500
# 1/1 [==============================] - 0s 100ms/step - loss: 0.4062 - val_loss: 0.3934 - lr: 0.1743
# Epoch 405/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.3984 - val_loss: 0.4385 - lr: 0.1743
# Epoch 406/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.4050 - val_loss: 0.3955 - lr: 0.1743
# Epoch 407/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3969 - val_loss: 0.4411 - lr: 0.1743
# Epoch 408/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4034 - val_loss: 0.3975 - lr: 0.1743
# Epoch 409/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3955 - val_loss: 0.4435 - lr: 0.1743
# Epoch 410/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.4021 - val_loss: 0.3995 - lr: 0.1743
# Epoch 411/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.3940 - val_loss: 0.4455 - lr: 0.1743
# Epoch 412/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.4006 - val_loss: 0.4014 - lr: 0.1743
# Epoch 413/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3926 - val_loss: 0.4473 - lr: 0.1743
# Epoch 414/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3993 - val_loss: 0.4032 - lr: 0.1743
# Epoch 415/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3912 - val_loss: 0.4489 - lr: 0.1743
# Epoch 416/500
# 1/1 [==============================] - ETA: 0s - loss: 0.3979
# Epoch 416: ReduceLROnPlateau reducing learning rate to 0.156905297935009.
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3979 - val_loss: 0.4049 - lr: 0.1743
# Epoch 417/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3899 - val_loss: 0.4461 - lr: 0.1569
# Epoch 418/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3931 - val_loss: 0.4100 - lr: 0.1569
# Epoch 419/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3862 - val_loss: 0.4428 - lr: 0.1569
# Epoch 420/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3881 - val_loss: 0.4119 - lr: 0.1569
# Epoch 421/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3850 - val_loss: 0.4446 - lr: 0.1569
# Epoch 422/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3869 - val_loss: 0.4137 - lr: 0.1569
# Epoch 423/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3839 - val_loss: 0.4464 - lr: 0.1569
# Epoch 424/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3858 - val_loss: 0.4154 - lr: 0.1569
# Epoch 425/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3827 - val_loss: 0.4482 - lr: 0.1569
# Epoch 426/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3848 - val_loss: 0.4172 - lr: 0.1569
# Epoch 427/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3816 - val_loss: 0.4500 - lr: 0.1569
# Epoch 428/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3837 - val_loss: 0.4189 - lr: 0.1569
# Epoch 429/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3805 - val_loss: 0.4519 - lr: 0.1569
# Epoch 430/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3826 - val_loss: 0.4208 - lr: 0.1569
# Epoch 431/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3794 - val_loss: 0.4540 - lr: 0.1569
# Epoch 432/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3816 - val_loss: 0.4228 - lr: 0.1569
# Epoch 433/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3783 - val_loss: 0.4564 - lr: 0.1569
# Epoch 434/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3806 - val_loss: 0.4250 - lr: 0.1569
# Epoch 435/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3772 - val_loss: 0.4593 - lr: 0.1569
# Epoch 436/500
# 1/1 [==============================] - ETA: 0s - loss: 0.3797
# Epoch 436: ReduceLROnPlateau reducing learning rate to 0.14121476411819459.
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3797 - val_loss: 0.4274 - lr: 0.1569
# Epoch 437/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3761 - val_loss: 0.4595 - lr: 0.1412
# Epoch 438/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3766 - val_loss: 0.4345 - lr: 0.1412
# Epoch 439/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3728 - val_loss: 0.4599 - lr: 0.1412
# Epoch 440/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3729 - val_loss: 0.4410 - lr: 0.1412
# Epoch 441/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3709 - val_loss: 0.4659 - lr: 0.1412
# Epoch 442/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3708 - val_loss: 0.4472 - lr: 0.1412
# Epoch 443/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3693 - val_loss: 0.4751 - lr: 0.1412
# Epoch 444/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3702 - val_loss: 0.4347 - lr: 0.1412
# Epoch 445/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3755 - val_loss: 0.4717 - lr: 0.1412
# Epoch 446/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3753 - val_loss: 0.4226 - lr: 0.1412
# Epoch 447/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3557 - val_loss: 0.3980 - lr: 0.1412
# Epoch 448/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3356 - val_loss: 0.3854 - lr: 0.1412
# Epoch 449/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3846 - val_loss: 0.5244 - lr: 0.1412
# Epoch 450/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3781 - val_loss: 0.5294 - lr: 0.1412
# Epoch 451/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3384 - val_loss: 0.5575 - lr: 0.1412
# Epoch 452/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4227 - val_loss: 0.3523 - lr: 0.1412
# Epoch 453/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3420 - val_loss: 0.3742 - lr: 0.1412
# Epoch 454/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3368 - val_loss: 1.3284 - lr: 0.1412
# Epoch 455/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3999 - val_loss: 0.3584 - lr: 0.1412
# Epoch 456/500
# 1/1 [==============================] - ETA: 0s - loss: 0.3381
# Epoch 456: ReduceLROnPlateau reducing learning rate to 0.1270932823419571.
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3381 - val_loss: 0.4068 - lr: 0.1412
# Epoch 457/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3129 - val_loss: 0.3997 - lr: 0.1271
# Epoch 458/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3080 - val_loss: 1.0715 - lr: 0.1271
# Epoch 459/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3903 - val_loss: 0.4166 - lr: 0.1271
# Epoch 460/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3642 - val_loss: 0.4414 - lr: 0.1271
# Epoch 461/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3536 - val_loss: 0.4697 - lr: 0.1271
# Epoch 462/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3303 - val_loss: 0.4550 - lr: 0.1271
# Epoch 463/500
# 1/1 [==============================] - 0s 135ms/step - loss: 0.3742 - val_loss: 0.3446 - lr: 0.1271
# Epoch 464/500
# 1/1 [==============================] - 0s 193ms/step - loss: 0.3161 - val_loss: 0.3639 - lr: 0.1271
# Epoch 465/500
# 1/1 [==============================] - 0s 132ms/step - loss: 0.3571 - val_loss: 0.4530 - lr: 0.1271
# Epoch 466/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.3135 - val_loss: 0.5302 - lr: 0.1271
# Epoch 467/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.3648 - val_loss: 0.5357 - lr: 0.1271
# Epoch 468/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3637 - val_loss: 0.5302 - lr: 0.1271
# Epoch 469/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3620 - val_loss: 0.5339 - lr: 0.1271
# Epoch 470/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3612 - val_loss: 0.5312 - lr: 0.1271
# Epoch 471/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3603 - val_loss: 0.5339 - lr: 0.1271
# Epoch 472/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.3596 - val_loss: 0.5328 - lr: 0.1271
# Epoch 473/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3589 - val_loss: 0.5350 - lr: 0.1271
# Epoch 474/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.3581 - val_loss: 0.5349 - lr: 0.1271
# Epoch 475/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3572 - val_loss: 0.5371 - lr: 0.1271
# Epoch 476/500
# 1/1 [==============================] - ETA: 0s - loss: 0.3559
# Epoch 476: ReduceLROnPlateau reducing learning rate to 0.1143839567899704.
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3559 - val_loss: 0.5380 - lr: 0.1271
# Epoch 477/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3539 - val_loss: 0.5403 - lr: 0.1144
# Epoch 478/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3505 - val_loss: 0.5417 - lr: 0.1144
# Epoch 479/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3431 - val_loss: 0.5391 - lr: 0.1144
# Epoch 480/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3266 - val_loss: 0.5180 - lr: 0.1144
# Epoch 481/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3095 - val_loss: 0.5746 - lr: 0.1144
# Epoch 482/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3600 - val_loss: 0.5700 - lr: 0.1144
# Epoch 483/500
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3586 - val_loss: 0.5695 - lr: 0.1144
# Epoch 484/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3578 - val_loss: 0.5674 - lr: 0.1144
# Epoch 485/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3572 - val_loss: 0.5672 - lr: 0.1144
# Epoch 486/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3567 - val_loss: 0.5662 - lr: 0.1144
# Epoch 487/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3563 - val_loss: 0.5662 - lr: 0.1144
# Epoch 488/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3559 - val_loss: 0.5659 - lr: 0.1144
# Epoch 489/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3556 - val_loss: 0.5660 - lr: 0.1144
# Epoch 490/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3552 - val_loss: 0.5660 - lr: 0.1144
# Epoch 491/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3549 - val_loss: 0.5663 - lr: 0.1144
# Epoch 492/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3545 - val_loss: 0.5665 - lr: 0.1144
# Epoch 493/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3542 - val_loss: 0.5669 - lr: 0.1144
# Epoch 494/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3539 - val_loss: 0.5672 - lr: 0.1144
# Epoch 495/500
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3536 - val_loss: 0.5676 - lr: 0.1144
# Epoch 496/500
# 1/1 [==============================] - ETA: 0s - loss: 0.3533
# Epoch 496: ReduceLROnPlateau reducing learning rate to 0.10294556245207787.
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3533 - val_loss: 0.5680 - lr: 0.1144
# Epoch 497/500
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3530 - val_loss: 0.5685 - lr: 0.1029
# Epoch 498/500
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3527 - val_loss: 0.5690 - lr: 0.1029
# Epoch 499/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3524 - val_loss: 0.5695 - lr: 0.1029
# Epoch 500/500
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3521 - val_loss: 0.5700 - lr: 0.1029

# %% [markdown]
# ## Test

# %%
import plotly.graph_objects as go


layout = go.Layout(width=800, height=600)
x1_nn_train_pred = model_x1.predict([X_train[:, :2]])
fig3 = go.Figure(data=go.Scatter3d(x=X_train[:, 0], y=X_train[:, 1], z=x1_nn_train_pred[:,0],
                                   mode='markers', marker=dict(size=5), name='train'), layout=layout)

x1_nn_test_pred = model_x1.predict([X_test[:, :2]])
fig3.add_trace(go.Scatter3d(x=X_test[:, 0], y=X_test[:, 1], z=x1_nn_test_pred[:,0],
                            mode='markers', marker=dict(size=5), name='test'))
fig3.show()

layout = go.Layout(width=800, height=600)
X1_mesh, X2_mesh = np.meshgrid(np.linspace(np.min(X[:,0]), np.max(X[:,0]), 20), np.linspace(0., np.max(X[:,1]), 20))
x1_mesh, x2_mesh = np.ravel(X1_mesh).reshape((-1, 1)), np.ravel(X2_mesh).reshape((-1, 1))
X1_mesh = np.hstack((x1_mesh, x2_mesh))
y_mesh = model_x1.predict([X1_mesh])
fig4 = go.Figure(data=go.Scatter3d(x=x1_mesh.ravel(), y=x2_mesh.ravel(), z=y_mesh.ravel(),
                                   mode='markers', marker=dict(size=5)), layout=layout)
fig4.show()
# Out:
# 5/5 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 30ms/step
# 13/13 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Robustness testing

# %%
X_equal = np.array([features_lf_1.loc[:, 'speed'].values, features_lf_1.loc[:, 'z_rolling_rms'].values, 
              features_lf_2_matched.loc[:, 'speed'].values, features_lf_2_matched.loc[:, 'z_rolling_rms'].values]).T
y_equal = np.zeros((X_equal.shape[0], 1))

x1_1_pred = model_x1.predict([X_equal[:, :2]])
x1_2_pred = model_x1.predict([X_equal[:, 2:]])

fig, ax = plt.subplots(3, 1, figsize=(15,9))
ax[0].plot(X_equal[:, 0], color='blue', linestyle='-', label='speed_1')
ax[0].plot(X_equal[:, 2], color='red', linestyle='-', label='speed_2')
ax[0].legend()
ax[1].plot(X_equal[:, 1], color='blue', linestyle='-', label='acc_1')
ax[1].plot(X_equal[:, 3], color='red', linestyle='-', label='acc_2')
ax[1].fill_between(np.linspace(0,x1_1_pred.shape[0]-1,x1_1_pred.shape[0]), 
                   (X_equal[:, 1]).ravel(), 
                   (X_equal[:, 3]).ravel(), 
                   color='grey', alpha=0.3)  # Adjust alpha for transparency if needed
ax[1].legend()
ax[2].plot(x1_1_pred, color='blue', linestyle='-', label='f_1')
ax[2].plot(x1_2_pred, color='red', linestyle='-', label='f_2')
ax[2].fill_between(np.linspace(0,x1_1_pred.shape[0]-1,x1_1_pred.shape[0]), 
                   (x1_1_pred).ravel(), 
                   (x1_2_pred).ravel(), 
                   color='grey', alpha=0.3)  # Adjust alpha for transparency if needed
ax[2].legend()
ax[2].set_xlabel('sample')
# ax[3].plot((x1_1_pred+x1_2_pred)/2, color='green', linestyle='-', label='f_m')
# ax[3].fill_between(np.linspace(0,x1_1_pred.shape[0],x1_1_pred.shape[0]), 
#                    (x1_1_pred).ravel(), 
#                    (x1_2_pred).ravel(), 
#                    color='grey', alpha=0.3)  # Adjust alpha for transparency if needed

# ax[3].legend()
# ax[3].set_xlabel('sample')
# Out:
# 3/3 [==============================] - 1s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# Text(0.5, 0, 'sample')

# %%
circ_rad = 10

# Create a map centered at the mean latitude and longitude of loc_orig_df_2
center_lat = loc_orig_df_1['latitude'].mean()
center_lon = loc_orig_df_1['longitude'].mean()
mymap = folium.Map(location=[center_lat, center_lon], zoom_start=10, tiles='OpenStreetMap')

f1, f2 = x1_1_pred[:,0], x1_2_pred[:,0]
f1, f2 = f1-np.min(f1), f2-np.min(f2)
f1, f2 = f1/np.max(f1), f2/np.max(f2)

# Plot the latitude and longitude data on the map
for index in range(loc_orig_df_1.shape[0]):
    row1, row2 = loc_orig_df_1.iloc[index,:], loc_orig_df_2_matched.iloc[index,:]
    folium.Circle([row1['latitude'], row1['longitude']],
                        radius=circ_rad*f1[index],
                        color='blue',
                        fill=False,
                        fill_color='blue').add_to(mymap)
    folium.Circle([row2['latitude'], row2['longitude']],
                        radius=circ_rad*f2[index],
                        color='red',
                        fill=False,
                        fill_color='red').add_to(mymap)

# Save the map to an HTML file
mymap.save("map_f.html")

# %%
circ_rad = 5

# Create a map centered at the mean latitude and longitude of loc_orig_df_2
center_lat = loc_orig_df_1['latitude'].mean()
center_lon = loc_orig_df_1['longitude'].mean()
mymap = folium.Map(location=[center_lat, center_lon], zoom_start=10, tiles='OpenStreetMap')

acc1, acc2 = X_equal[:, 1], X_equal[:, 3]
acc1, acc2 = acc1-np.min(acc1), acc2-np.min(acc2)
acc1, acc2 = acc1/np.max(acc1), acc2/np.max(acc2)

# Plot the latitude and longitude data on the map
for index in range(loc_orig_df_1.shape[0]):
    row1, row2 = loc_orig_df_1.iloc[index,:], loc_orig_df_2_matched.iloc[index,:]
    folium.Circle([row1['latitude'], row1['longitude']],
                        radius=circ_rad*acc1[index],
                        color='blue',
                        fill=False,
                        fill_color='blue').add_to(mymap)
    folium.Circle([row2['latitude'], row2['longitude']],
                        radius=circ_rad*acc2[index],
                        color='red',
                        fill=False,
                        fill_color='red').add_to(mymap)

# Save the map to an HTML file
mymap.save("map_acc.html")

# %% [markdown]
# ### Correlations

# %%
# acceleration correlation
fig, ax = plt.subplots(1, 2, figsize=(6, 3), sharex='all', sharey=all)
ax[0].plot(acc1, acc2, linestyle='', color='blue', marker='.', label=f'r={np.round(np.corrcoef(acc1, acc2)[1,0], 2)}')
ax[0].set_xlabel('acc_1')
ax[0].set_ylabel('acc_2')
ax[0].legend()
ax[1].plot(f1, f2, linestyle='', color='red', marker='.', label=f'r={np.round(np.corrcoef(f1, f2)[1,0], 2)}')
ax[1].set_xlabel('f_1')
ax[1].set_ylabel('f_2')
ax[1].legend()
plt.show()


# acceleration correlation
acc_low = np.vstack((acc1, acc2)).T
acc_low = acc_low[(acc_low[:, 0] < 0.5) & (acc_low[:, 1] < 0.5), :]
acc1_low, acc2_low = acc_low[:, 0], acc_low[:, 1]
f_low = np.vstack((f1, f2)).T
f_low = f_low[(f_low[:, 0] < 0.5) & (f_low[:, 1] < 0.5), :]
f1_low, f2_low = f_low[:, 0], f_low[:, 1]

fig, ax = plt.subplots(1, 2, figsize=(6, 3), sharex='all', sharey=all)
ax[0].plot(acc1_low, acc2_low, linestyle='', color='blue', marker='.', label=f'r={np.round(np.corrcoef(acc1_low, acc2_low)[1,0], 2)}')
ax[0].set_xlabel('acc_1')
ax[0].set_ylabel('acc_2')
ax[0].legend()
ax[1].plot(f1_low, f2_low, linestyle='', color='red', marker='.', label=f'r={np.round(np.corrcoef(f1_low, f2_low)[1,0], 2)}')
ax[1].set_xlabel('f_1')
ax[1].set_ylabel('f_2')
ax[1].legend()
